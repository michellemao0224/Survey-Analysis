# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

from subprocess import check_output
print(check_output(["ls", "../Survey_Classification"]).decode("utf8"))
# Out:
# 1-s2.0-S2090447914000550-gr1.jpg
# 1-s2.0-S2090447914000550-main.pdf
# CleanSurvey.csv
# Survey.csv
# Survey_Classification_v1.ipynb
# Survey_Classification_v2.ipynb

# %%
df=pd.read_csv("../Survey_Classification/Survey.csv")

# %%
df.head()
# Out:
#           Time Started       Date Submitted    Status  \
# 0  2015-12-21 22:21:47  2015-12-21 22:21:51   Partial
# 1  2015-12-22 00:03:36  2015-12-22 00:26:01  Complete
# 2  2015-12-22 00:17:49  2015-12-22 00:17:49   Partial
# 3  2015-12-22 00:22:07  2015-12-22 00:24:02   Partial
# 4  2015-12-22 00:41:40  2015-12-22 00:42:09   Partial
#
#   How often do you use Jupyter Notebook?  \
# 0                                    NaN
# 1                                  Daily
# 2                                    NaN
# 3                                  Daily
# 4                                 Weekly
#
#   What, if anything, hinders you from making Jupyter Notebook an even more regular part of your workflow?  \
# 0                                                NaN
# 1  Ways to hide helper function definitions (or e...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Roughly how long have you been using Jupyter Notebook?  \
# 0                                                NaN
# 1                                 Less than one year
# 2                                                NaN
# 3                                   One year or more
# 4                                   One year or more
#
#   Tool / Application #1:What tools and applications, if any, would you like to see more tightly integrated with Jupyter Notebook?      \
# 0                                                NaN
# 1                                         sqlalchemy
# 2                                                NaN
# 3                 version control on notebooks (git)
# 4                                                NaN
#
#   Tool / Application #2:What tools and applications, if any, would you like to see more tightly integrated with Jupyter Notebook?      \
# 0                                                NaN
# 1  bokeh (or other JS/interactive plotting packages)
# 2                                                NaN
# 3                              publishing dashboards
# 4                                                NaN
#
#   Tool / Application #3:What tools and applications, if any, would you like to see more tightly integrated with Jupyter Notebook?      \
# 0                                                NaN
# 1  diff tool for changes in src (primarily for gi...
# 2                                                NaN
# 3                                 dockerised kernels
# 4                                                NaN
#
#   How do you run the Jupyter Notebook?  \
# 0                                  NaN
# 1          As a standalone application
# 2                                  NaN
# 3                  Through Jupyter Hub
# 4          As a standalone application
#
#                                                                                                                                                   ...                                                                                                                                                   \
# 0                                                                                                                                                 ...
# 1                                                                                                                                                 ...
# 2                                                                                                                                                 ...
# 3                                                                                                                                                 ...
# 4                                                                                                                                                 ...
#
#   Enhancement #2:Thinking back to when you first started using Jupyter Notebook, what enhancements would have made your initial experience better?  \
# 0                                                NaN
# 1  easier callbacks with ipywidgets / ways to get...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Enhancement #3:Thinking back to when you first started using Jupyter Notebook, what enhancements would have made your initial experience better?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Select all the words that best describe Jupyter Notebook.  \
# 0                                                NaN
# 1                        comfortable;intuitive;quick
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Other word(s)::Select all the words that best describe Jupyter Notebook.  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   What is your primary role when using Jupyter Notebook (e.g., student, astrophysicist, financial modeler, business manager, etc.)?  \
# 0                                                NaN
# 1          grad student (computational astrophysics)
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   How many years have you been in this role?   \
# 0                                         NaN
# 1                                      1 year
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#   Industry #1:What industries does your role and analytical work support (e.g., Journalism, IT, etc.)?  \
# 0                                                NaN
# 1                                   academic science
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Industry #2:What industries does your role and analytical work support (e.g., Journalism, IT, etc.)?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Industry #3:What industries does your role and analytical work support (e.g., Journalism, IT, etc.)?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   How many people typically see and/or interact with the results of your work in Jupyter Notebook? (Consider people who view your notebooks on nbviewer, colleagues who rerun your notebooks, developers who star your notebook repos on GitHub, audiences who see your notebooks as slideshows, etc.)
# 0                                                NaN
# 1                                               Tens
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 37 columns]

# %%
df_s = df.copy()

# %%
df_s = df_s.rename(columns = {'What, if anything, hinders you from making Jupyter Notebook an even more regular part of your workflow?':
                              'Constrains'})

# %%
df_s.head()
# Out:
#           Time Started       Date Submitted    Status  \
# 0  2015-12-21 22:21:47  2015-12-21 22:21:51   Partial
# 1  2015-12-22 00:03:36  2015-12-22 00:26:01  Complete
# 2  2015-12-22 00:17:49  2015-12-22 00:17:49   Partial
# 3  2015-12-22 00:22:07  2015-12-22 00:24:02   Partial
# 4  2015-12-22 00:41:40  2015-12-22 00:42:09   Partial
#
#   How often do you use Jupyter Notebook?  \
# 0                                    NaN
# 1                                  Daily
# 2                                    NaN
# 3                                  Daily
# 4                                 Weekly
#
#                                           Constrains  \
# 0                                                NaN
# 1  Ways to hide helper function definitions (or e...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Roughly how long have you been using Jupyter Notebook?  \
# 0                                                NaN
# 1                                 Less than one year
# 2                                                NaN
# 3                                   One year or more
# 4                                   One year or more
#
#   Tool / Application #1:What tools and applications, if any, would you like to see more tightly integrated with Jupyter Notebook?      \
# 0                                                NaN
# 1                                         sqlalchemy
# 2                                                NaN
# 3                 version control on notebooks (git)
# 4                                                NaN
#
#   Tool / Application #2:What tools and applications, if any, would you like to see more tightly integrated with Jupyter Notebook?      \
# 0                                                NaN
# 1  bokeh (or other JS/interactive plotting packages)
# 2                                                NaN
# 3                              publishing dashboards
# 4                                                NaN
#
#   Tool / Application #3:What tools and applications, if any, would you like to see more tightly integrated with Jupyter Notebook?      \
# 0                                                NaN
# 1  diff tool for changes in src (primarily for gi...
# 2                                                NaN
# 3                                 dockerised kernels
# 4                                                NaN
#
#   How do you run the Jupyter Notebook?  \
# 0                                  NaN
# 1          As a standalone application
# 2                                  NaN
# 3                  Through Jupyter Hub
# 4          As a standalone application
#
#                                                                                                                                                   ...                                                                                                                                                   \
# 0                                                                                                                                                 ...
# 1                                                                                                                                                 ...
# 2                                                                                                                                                 ...
# 3                                                                                                                                                 ...
# 4                                                                                                                                                 ...
#
#   Enhancement #2:Thinking back to when you first started using Jupyter Notebook, what enhancements would have made your initial experience better?  \
# 0                                                NaN
# 1  easier callbacks with ipywidgets / ways to get...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Enhancement #3:Thinking back to when you first started using Jupyter Notebook, what enhancements would have made your initial experience better?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Select all the words that best describe Jupyter Notebook.  \
# 0                                                NaN
# 1                        comfortable;intuitive;quick
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Other word(s)::Select all the words that best describe Jupyter Notebook.  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   What is your primary role when using Jupyter Notebook (e.g., student, astrophysicist, financial modeler, business manager, etc.)?  \
# 0                                                NaN
# 1          grad student (computational astrophysics)
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   How many years have you been in this role?   \
# 0                                         NaN
# 1                                      1 year
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#   Industry #1:What industries does your role and analytical work support (e.g., Journalism, IT, etc.)?  \
# 0                                                NaN
# 1                                   academic science
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Industry #2:What industries does your role and analytical work support (e.g., Journalism, IT, etc.)?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Industry #3:What industries does your role and analytical work support (e.g., Journalism, IT, etc.)?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   How many people typically see and/or interact with the results of your work in Jupyter Notebook? (Consider people who view your notebooks on nbviewer, colleagues who rerun your notebooks, developers who star your notebook repos on GitHub, audiences who see your notebooks as slideshows, etc.)
# 0                                                NaN
# 1                                               Tens
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 37 columns]

# %%
null_list = ['nothing', 'Nothing!', 'Nothing',
             'n/a', 'Nothing.', 'N/A', 'None',
             'none','No further need', 'hh',
             'Nothing so far!','nothing I can think of',' ']

for phrase in null_list:
    df_s.Constrains.replace(phrase, ' ', inplace=True)

# %%
df_s.Constrains.str.lower()
# Out:
# 0                                                     NaN
# 1       ways to hide helper function definitions (or e...
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# 5                                                lazyness
# 6       having to setup a jupyter server in a particul...
# 7       - a standard option of converting the notebook...
# 8       mainly two missing features: 1. collapsable se...
# 9       maybe figure out how to schedule automated exe...
# 10         don't use it to teach all of my courses (yet).
# 11      browser becomes unresponsive when i start a to...
# 12                                real time collaboration
# 13      my coworkers do not use them. keybindings clas...
# 14                                        git integration
# 15      corporate it policy colleagues' lack of knowle...
# 16      it is very easy to do exploratory computing, b...
# 17                                                    NaN
# 18                                                    NaN
# 19                                                    NaN
# 20                                                    NaN
# 21      not too easy to integrate into a git workflow ...
# 22      poor experience opening notebooks in arbitrary...
# 23       ide capabilities: debugging ui, refactorings,...
# 24                   working on notebooks collaboratively
# 25                                                    NaN
# 26      lack of multi-cell copy/paste (until now). dif...
# 27      hub support for windows. better kernel reliabi...
# 28      improved workflow to create reports with it. j...
# 29      mostly, the fact that not many colleagues, col...
#                               ...
# 1676                                                  NaN
# 1677    exporting notebooks to other formats, such as ...
# 1678    slow. doesn't handle large datasets well - cra...
# 1679                                                  NaN
# 1680                                                  NaN
# 1681    we need a way to hide the code to create a bet...
# 1682                                                  NaN
# 1683    mostly support for collaboration: multi-user s...
# 1684                                                  NaN
# 1685                                                  NaN
# 1686    difficulty sharing results with collaborators ...
# 1687                                                  NaN
# 1688                                                  NaN
# 1689                                                  NaN
# 1690                  no strong complaints at the moment.
# 1691    text-block weakness: - absence of latex-like c...
# 1692                                                  NaN
# 1693    would be great to have more advanced editor fe...
# 1694                                                  NaN
# 1695    - not very handy to inspect large dataframes (...
# 1696                                                  NaN
# 1697    i still use the qt backend sometimes with matp...
# 1698                                                  NaN
# 1699                                                  NaN
# 1700                                                  NaN
# 1701    having an awk specific version would be useful...
# 1702    single window of browser lack of integration w...
# 1703                              right tool for the job.
# 1704                                                  NaN
# 1705                                                  NaN
# Name: Constrains, Length: 1706, dtype: object

# %%
df_s.Constrains.str.strip()
# Out:
# 0                                                     NaN
# 1       Ways to hide helper function definitions (or e...
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# 5                                                lazyness
# 6       Having to setup a Jupyter server in a particul...
# 7       - a standard option of converting the notebook...
# 8       Mainly two missing features: 1. Collapsable se...
# 9       Maybe figure out how to schedule automated exe...
# 10         Don't use it to teach all of my courses (yet).
# 11      Browser becomes unresponsive when I start a to...
# 12                                real time collaboration
# 13      My coworkers do not use them. Keybindings clas...
# 14                                        git integration
# 15      Corporate IT policy Colleagues' lack of knowle...
# 16      It is very easy to do exploratory computing, b...
# 17                                                    NaN
# 18                                                    NaN
# 19                                                    NaN
# 20                                                    NaN
# 21      not too easy to integrate into a git workflow ...
# 22      Poor experience opening notebooks in arbitrary...
# 23       IDE capabilities: debugging UI, refactorings,...
# 24                   working on notebooks collaboratively
# 25                                                    NaN
# 26      Lack of multi-cell copy/paste (until now). Dif...
# 27      Hub support for Windows. Better kernel reliabi...
# 28      Improved workflow to create reports with it. J...
# 29      Mostly, the fact that not many colleagues, col...
#                               ...
# 1676                                                  NaN
# 1677    Exporting notebooks to other formats, such as ...
# 1678    Slow. Doesn't handle large datasets well - cra...
# 1679                                                  NaN
# 1680                                                  NaN
# 1681    we need a way to hide the code to create a bet...
# 1682                                                  NaN
# 1683    mostly support for collaboration: multi-user s...
# 1684                                                  NaN
# 1685                                                  NaN
# 1686    Difficulty sharing results with collaborators ...
# 1687                                                  NaN
# 1688                                                  NaN
# 1689                                                  NaN
# 1690                  No strong complaints at the moment.
# 1691    Text-block weakness: - absence of LaTeX-like c...
# 1692                                                  NaN
# 1693    Would be great to have more advanced editor fe...
# 1694                                                  NaN
# 1695    - Not very handy to inspect large dataframes (...
# 1696                                                  NaN
# 1697    I still use the Qt backend sometimes with matp...
# 1698                                                  NaN
# 1699                                                  NaN
# 1700                                                  NaN
# 1701    Having an AWK specific version would be useful...
# 1702    Single window of browser Lack of integration w...
# 1703                              Right tool for the job.
# 1704                                                  NaN
# 1705                                                  NaN
# Name: Constrains, Length: 1706, dtype: object

# %%
df_s.to_csv('CleanSurvey.csv', encoding='utf-8')

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
import nltk
import re

# %%
function_list = ['function', 'folder', 'computer',
             'search', 'notebook','tool','pandas', 
             'cell','code','jupyter','feature','output','data','documentation','format',
                'stack','file','debugging','version','control','github',
                'directory','cursor','repo','kernel','command',
                'line','setting','use','setup','copy','paste','copying','pasting',
                'terminal','conda','ipython','python','button','input','output','auto',
                'testing','scratch','profile','uploading','downloading','upload','download','widget','customization',
                'default','reporting','analysis','diff','diffing','merge','mouse','git',
                'filesystem','way','github','thing','app','click','interface',
                'library','run','drag','drop','number','user','markdown',
                'debug','log','message','track','loop','http','ssh','render','nbdiff','save',
                'saving','context','application','debugger','print','printout','auth','array',
                'web','cut','spyder','merging','spell','checker','customization','startup',
                'share','ploting','network','haskell','identification','password',
                'cluster','plot','forwarding','cloud','block','region','error']

design_list = ['UI','website','html','explorer','bottom','screen','space','project','module','gui','script'
               'window','table','content','tree','browser','columns','multiline','text','editor','console',
              'desktop','panel','keyboard','vim','emacs','style','title','view','type','matlab','engine',
              'slide','export','site']

time_list = ['server','time','load','session','collaboration']

performance_list = ['computation','integration','representation','execution','simulation',
                    'solution','scope','interactivity','interaction','management','environment',
                    'team','secure','productivity','development','computing','artifact','ability','work',
                   'initialization','mode','production','group','memory','service',
                   'support','language','programming','volatility','installation','packaging','distribution',
                   'flexibility','workflow','visualisation','task','inability','persistence','platform','seamless',
                   'ad','hoc','exploratory','legacy','convenience','machine','usability','performance',
                   'storage','autocompletion','introspection','extension']

# %%
###
stopWords = set(stopwords.words("english"))
nouns = list()
for text in df_s.Constrains:
    if str(text) != 'nan':
        line = re.sub(r'[^\w]', ' ', str(text).lower())
        words = nltk.word_tokenize(line.decode('utf-8'))
        tagged = nltk.pos_tag(words)
        nouns.append([str(word) for word, tag in tagged if tag in 'NN' and len(word) > 1])
        
print(nouns)

# %%
###
fun_score = 0 
for noun in nouns:
    for words in noun:
        if words in function_list:
                fun_score = fun_score + 1
                print words

# %%
# define the function that computes the sentiment subject
def get_sentiment_subject(text):
    # tokenize and lemmatize the current survey
    stopWords = set(stopwords.words("english"))
    line = re.sub(r'[^\w]', ' ', str(text).lower())
    words = nltk.word_tokenize(line.decode('utf-8'))
    tagged = nltk.pos_tag(words)
    survey = iter([str(word) for word, tag in tagged if tag in 'NN' and len(word) > 1])

    # calculate the sentiment score
    function = 0
    design = 0
    time = 0
    performance = 0

    for word in survey:
        if word in function_list:
            function = function + 1
#             print "function +1", word
        if word in design_list:
            design = design + 1
#             print "design +1", word
        if word in time_list:
            time = time + 1
#             print "time +1", word
        if word in performance_list:
            performance = performance + 1
#             print "performance +1", word

    scores = ["function", "design", "time", "performance"]
    return max(scores, key = locals().get)

# apply it on our survey csv
for text in df_s.Constrains:
        if str(text) != 'nan':
            print "Comment: '{:s}', subject: {:s}".format(text, get_sentiment_subject(text))
            print "------------------------------------"
# Out:
# Comment: 'Ways to hide helper function definitions (or easier ways to import functions from notebooks). But those might be bad practices', subject: function
# ------------------------------------
# Comment: 'lazyness', subject: function
# ------------------------------------
# Comment: 'Having to setup a Jupyter server in a particular folder location before opening up a file (and then only having access to files beneath that folder). I wish I could navigate my computer just as I do with a File explorer, with search and preview options.   ', subject: function
# ------------------------------------
# Comment: '- a standard option of converting the notebook to html, pdf,... with or without code cells, input/output prompts.  - easy integration in a static website (e.g. sphinx, ...)  where that static website is used as a sort of reporting tool - when converting to a certain format (rst, md, ...) the rendering of the output (e.g. pandas dataframes) also in that format provided the package has implemented this (e.g. pandas dataframes: in te notebook html representation, when converted to markdown a markdown representation,...) ', subject: function
# ------------------------------------
# Comment: 'Mainly two missing features: 1. Collapsable sections 2. Multi-cell selection / copy-cut-paste', subject: function
# ------------------------------------
# Comment: 'Maybe figure out how to schedule automated execution of notebooks?', subject: performance
# ------------------------------------
# Comment: 'Don't use it to teach all of my courses (yet).', subject: function
# ------------------------------------
# Comment: 'Browser becomes unresponsive when I start a too intensive computation.  Poor integration with my preferred code editors (pycharm or vim).  ', subject: performance
# ------------------------------------
# Comment: 'real time collaboration', subject: time
# ------------------------------------
# Comment: 'My coworkers do not use them. Keybindings clash with vimperator.', subject: function
# ------------------------------------
# Comment: 'git integration', subject: performance
# ------------------------------------
# Comment: 'Corporate IT policy Colleagues' lack of knowledge of PyData stack', subject: function
# ------------------------------------
# Comment: 'It is very easy to do exploratory computing, but not so easy to persist results. I work in computational quantum physics, and in my "old" workflows, e.g., with Fortran codes, the computation and analysis were usually well-separated: The results from (potentially long-running) simulations were saved as text files, and then analyzed/plotted with, e.g., gnuplot.  Jupyter Notebook makes this more convenient by allowing me combine simulation and analysis in a single notebook without the intermediate step of saving text files and reading the data again. However, this also makes it much easier to "lose" results that only ever existed as data, but were not written to files. Going back to writing text files for all of the possibly interesting output would be a step back regarding the interactivity, so an easy way to save program state or something similar would be great. I realize this is not directly within the scope of the Jupyter Notebook, as it corresponds to a general persistence solution for Python, but it's definitely a pain point that is made more relevant by the dynamic nature of the Notebook.', subject: function
# ------------------------------------
# Comment: 'not too easy to integrate into a git workflow (diffs don't look nice and it is hard to see what has changed)', subject: function
# ------------------------------------
# Comment: 'Poor experience opening notebooks in arbitrary locations, e.g., not in the /home tree, as there's no "double-click file to start jupyter notebook" feature (yet, I'm hoping)', subject: function
# ------------------------------------
# Comment: 'IDE capabilities: debugging UI, refactorings,...', subject: function
# ------------------------------------
# Comment: 'working on notebooks collaboratively', subject: function
# ------------------------------------
# Comment: 'Lack of multi-cell copy/paste (until now). Difficulties with version control and large notebooks. Poor documentation in general. Relatively frequent changes to the notebook format.', subject: function
# ------------------------------------
# Comment: 'Hub support for Windows. Better kernel reliability on Windows.', subject: performance
# ------------------------------------
# Comment: 'Improved workflow to create reports with it. Just being able to cite papers from a bibtex file, spellchecking, reordering of chapters would be nice.', subject: function
# ------------------------------------
# Comment: 'Mostly, the fact that not many colleagues, collaborators and customers use it or are familiar with it.', subject: function
# ------------------------------------
# Comment: 'Time.', subject: time
# ------------------------------------
# Comment: 'Documentation on how to use scripts at launch like before and configure the thing.  ', subject: function
# ------------------------------------
# Comment: 'Lack of proper debugging tools (comparable to e.g. Eclipse IDE, Visual Studio or Matlab).', subject: function
# ------------------------------------
# Comment: 'I'm part of an analytic team that frequently works with sensitive data like medical data covered by HIPAA. Jupyter Hub might be ideal for us except that our IT management is unsure of its applicability in a secure setting. It might also need additional features related to user workspaces, definition of projects and analytic teams, and user-defined data and workbook sharing between projects and teams. ', subject: performance
# ------------------------------------
# Comment: 'Doesn't interact with git too well with lots of unimportant / temporary changes distracting from the real differences in a commit.', subject: function
# ------------------------------------
# Comment: 'I want Jupyter to act like a normal text editor app in which I can easily open files, without the hassle of starting it from the console in the right place. Simple double click opening for all ipynbs please ', subject: function
# ------------------------------------
# Comment: ' ', subject: function
# ------------------------------------
# Comment: '- tighter integration with version control - cross project/directory search of notebooks - deployable notebooks - persistent widgets ', subject: function
# ------------------------------------
# Comment: 'I use it despite the pain points.', subject: function
# ------------------------------------
# Comment: 'Lacking nice github integration Interactive figures are cumbersome (at least I haven't found the right tools)', subject: function
# ------------------------------------
# Comment: 'No code refactoring. Auto-complete gets super confused with indentations', subject: function
# ------------------------------------
# Comment: 'Give notebooks more editors/ide functionnality: easier file browsing, editing, serach and replace...', subject: function
# ------------------------------------
# Comment: 'Ability to easily move library code from notebooks to modules.', subject: function
# ------------------------------------
# Comment: ' ', subject: function
# ------------------------------------
# Comment: 'I haven't worked out how to integrate storing notebooks into my normal workflow. Do I store notebooks in the directory struction with my other data/notebooks.  How do I ensure that, by default, the output is visilble to non-notebook users. Do I end up with lots of notebook servers in different directories', subject: function
# ------------------------------------
# Comment: 'Code editing is inferior to IDEs', subject: function
# ------------------------------------
# Comment: '"cognitive load" of having too many steps: start "ipython notebook" (in a particular directory, which then almost uselessly takes over that terminal session), find the right notebook, start it up. I imagine that for most users the server is usually irrelevant. Why can't I just open/start a notebook?  (Note on Q3, below: do you really mean "Jupyter notebook" only, or "ipython", too? I am answering for the latter.', subject: function
# ------------------------------------
# Comment: 'Nothing ', subject: function
# ------------------------------------
# Comment: 'I am studying Jupyter Notebook at the college and I see that it will be very usefull to me at work.', subject: function
# ------------------------------------
# Comment: 'In Mathematica, for instance, you can collapse sections, subsections, and even cells. Make that possible in Jupiter Notebook, too, please.', subject: function
# ------------------------------------
# Comment: 'No standardised solution for version control (I think there are a few ad-hoc tools out there at present but would rather learn/use something with momentum behind it).  Unexpected scrolling between cells when move cursor/focus or execute a cell (particularly when using Firefox and when have large cells).  Difficult to keep on top of API changes and developments in associated components e.g. widgets; ipython-dev and jupyter mailing lists can help here but useful info tends to get rather buried amongst things pertaining only to dedicated developers (and sysadmins interested in jupyterhub configs).  (I still love the project to bits though :-))', subject: function
# ------------------------------------
# Comment: 'Sometimes I want to just play around with ideas, without storing them. Creating a notebook always means that a file with all the code remains until I manually delete it.', subject: function
# ------------------------------------
# Comment: 'Awkwardness in use cf. regular desktop editors - e.g. basic shortcuts for running a cell and making a new one vs. making a markdown one  Difficulty with installing (vast majority of) add-ons etc, no standardised way just getting off repos on GitHub and debugging the frequent errors (e.g. recently had to look in issues log of repo for how to install nbextensions properly when readme didnt guide right; rpy2 update changed the guidance on how to install and did not work so after a few hours I gave up trying to get R inside Python kernel NB; xonsh kernel did not work with the latest Jupyter version). I really like Jupyter and do my best to contribute with these issues when they come up but it feels rather in development still (which is totally fine but not great for my productivity)  ...also the fact that I'm fairly new to using Jupyter NBs probably holds me back :-)', subject: function
# ------------------------------------
# Comment: 'The file browser feels clunky,  and I REALLY wish the checkpoint feature inside the notebooks would be implemented more completely. Autosaving is great, but not if we can only revert to the last save state. More save history!', subject: function
# ------------------------------------
# Comment: ' ', subject: function
# ------------------------------------
# Comment: 'I mostly write libraries.  Notebooks are not the right artifact for non-interactive computing.', subject: performance
# ------------------------------------
# Comment: 'I use the notebook for prototyping python code. I would love the ability to live-edit a module in one cell and interact with it in others.', subject: function
# ------------------------------------
# Comment: 'It doesn't do SAS,  which is about half my work, the other half is Python. ', subject: performance
# ------------------------------------
# Comment: 'Development environment, but it is about as regular as can be', subject: performance
# ------------------------------------
# Comment: 'The one dimensional interface.  It seems designed to be a single document rather than an complete interface. If you think about other powerful and ubiquitous software platforms, like Adobe Illustrator or Matlab, they often are designed around panels that expose useful information or interaction.  For example, an editor, variable browser, command line, etc.  I wish there were also multiple views within the Jupyter Notebook.', subject: function
# ------------------------------------
# Comment: 'I would appreciate to be also able to launch ipython notebook in a separate gui than the browser.', subject: design
# ------------------------------------
# Comment: 'I don't actually use it for work, but for classes. If I did, thought, Jupyter would prove itself a great tool.', subject: function
# ------------------------------------
# Comment: 'Git integration, CSS themes', subject: performance
# ------------------------------------
# Comment: ' ', subject: function
# ------------------------------------
# Comment: 'better connections to external DBs, easier interact widgets.', subject: function
# ------------------------------------
# Comment: 'Installation / initialization of Jupyter', subject: performance
# ------------------------------------
# Comment: 'I find it difficult to collaborate with colleagues who are all using Git. It is much easier to do this with plain Python files.', subject: function
# ------------------------------------
# Comment: 'already a part of my workflow. Being able to convert from notebook to script is very important but I wish I could just run my notebook in production mode.', subject: function
# ------------------------------------
# Comment: 'They are difficult to use with version control, and I prefer development in a text editor over development in a browser window.', subject: design
# ------------------------------------
# Comment: 'Sharing results in something like excel, which is still the de facto among our analysts, is sometimes difficult. ', subject: function
# ------------------------------------
# Comment: 'The ability to easily add your own hooks/scripts to extend functionality. This is fairly complex at this point.', subject: performance
# ------------------------------------
# Comment: 'Integration with version control and production code', subject: function
# ------------------------------------
# Comment: ' ', subject: function
# ------------------------------------
# Comment: 'lack of built-in versioning / organizational tools in the UI, need to go to the command line for configuration, and the fact that those configurations are difficult to make global for all of my users.', subject: function
# ------------------------------------
# Comment: 'static checking of code (ala pyflakes)  better integration with version control  better editor inside the code blocks', subject: function
# ------------------------------------
# Comment: 'Version control with git. Cell merging. Cell grouping and hiding. Vim key bindings. ', subject: function
# ------------------------------------
# Comment: 'I am only a beginner programmer', subject: function
# ------------------------------------
# Comment: 'My work group lives and breathes in Excel, so once we move a lot of our data into a more usable format than SAP, we might be able to do in a notebook setting', subject: function
# ------------------------------------
# Comment: 'The only time I don't use it is when I need to run a script that needs to go for several hours on end.  Or for tasks that I need to pass along to others.', subject: function
# ------------------------------------
# Comment: '- Not available on all my computing environments and I have been struggling with jupyterhub setup. - No easy workflow with a version control system such as git .  Need a markup language in comments to  create a mapping between notebook cells and traditional flat files. - Detect running dependencies between cells.  Warn when a variable is reassigned between cells .   This might indicate a cell cannot be refreshed without refreshing the previous one.', subject: function
# ------------------------------------
# Comment: 'Challenge setting up other language integrations aside Python. I tried the IScala integration and had a lot difficulty so went back to using the normal Scala REPL. I will like to be able to use R, Julia and Scala with Jupyter eventually also.', subject: function
# ------------------------------------
# Comment: 'I prefer developing in a full IDE, like PyCharm.', subject: function
# ------------------------------------
# Comment: 'I don't use Python often enough', subject: function
# ------------------------------------
# Comment: 'No automatic collaboration. Kernel crashing under memory stress where python thorough command line does not. ', subject: function
# ------------------------------------
# Comment: 'It doesn't work well with standard version control tools because one line of code doesn't correspond to one line in the notebook file  It throws away 30 years of text editor development by replacing a real editor like vim or emacs with a HTML text area.', subject: function
# ------------------------------------
# Comment: 'I don't spent all the time coding/analysing ', subject: time
# ------------------------------------
# Comment: 'Lack of a project view, inter-notebook copy/pasting of cells.  Not being able to export a Notebook removing code cells but leaving outputs.', subject: function
# ------------------------------------
# Comment: 'Number one complaint I have had is the lack of find and replace, autocomplete, and other text-editor style tools. I understand this may not really be the point of jupyter nootbooks, but I find myself cutting code, pasting to a text editor, and pasting back in all the time. In my limited experience (could easily be wrong about this), it doesn't have great integration with virtualenv, so it's a bit of a headache to switch from one env to another and reconfigure jupyter. On the nitpick side, translation of magic commands to equivalent python commands would be amazing when exporting to a .py file. ', subject: function
# ------------------------------------
# Comment: 'I'd like to use the jupyterhub with my colleagues but it is available only on linux and we live, unfortunately, in a win environment ', subject: performance
# ------------------------------------
# Comment: 'Nothing, it's just not always the appropriate tool.', subject: function
# ------------------------------------
# Comment: 'I prefer to use a real editor (vim, emacs) and a terminal for my Python scripts, not small boxes.', subject: design
# ------------------------------------
# Comment: 'It's not as nice an 'editor' as a 'proper' programmers text editor (such as Emacs, Sublime, Atom etc).  It can be tricky to scroll up and down and deal with large cells with lots of code.  It's difficult to run an IPython Notebook server that has support for both Py2 and Py3 kernels - ideally, there should be some way to integrate with conda so that you can easily start kernels in any conda environment.  Similarly, I often end up with multiple 'ipython notebook' commands (from the Terminal) running at once, as I want them to be in multiple different directories and in multiple conda environments. Combining this with the previous point: it'd be great if I could have it running as a service (or something similar), and then could just easily create a kernel from any conda environment, and navigate to the right folder - and have it all 'just work' without having to run new servers all the time', subject: function
# ------------------------------------
# Comment: 'Have to use the browser', subject: design
# ------------------------------------
# Comment: 'I usually use emacs.', subject: design
# ------------------------------------
# Comment: 'I don't know how to run tests. Sometimes not practical with narrow screen (half a screen)  ', subject: design
# ------------------------------------
# Comment: 'Some issues with NB convert to PDF, the templates for latex seem overly complex.. and no option for simpler, similarly the plug-ins are kind of messed up at the moment, also need 2.11 Scala support', subject: performance
# ------------------------------------
# Comment: 'moving between coding snippets in the notebook to making changes in another editor/ide. ', subject: function
# ------------------------------------
# Comment: 'I strongly use version control, and the workflow of using the notebook with version control is odd.', subject: function
# ------------------------------------
# Comment: 'Dealing with more than one programming language.', subject: performance
# ------------------------------------
# Comment: 'In my setup - I create interactive notebooks for analysts to use - I have some code (that will run and create a button) that will hid all the input cells (since the code can get long) and just shows the outputs which are ipython widgets and bokeh plots.  While I get along with it - if there are others like me perhaps that could be one of the buttons on the notebook tool bar (to toggle the input cells).', subject: function
# ------------------------------------
# Comment: 'Collaboration and versionning capabilities ', subject: time
# ------------------------------------
# Comment: '* The fact that it requires opening a new browser window (I might not want to open a browser at all, or add a tab inside my current/default browser) * The volatility of the environment (it's not easy to have an overview of how many notebooks are open, and their working folder etc.)', subject: function
# ------------------------------------
# Comment: 'The difficulty with using the same code in the notebook and running it from the command line. Inability to put code in the notebook under version control (git). ', subject: function
# ------------------------------------
# Comment: 'Not clear what needs to be installed and what versions, particularly WRT widgets & extensions.  I'm very excited about dashboards and can appreciate how fluid things are.  Finding it difficult figuring out where & how to jump in.', subject: function
# ------------------------------------
# Comment: 'I don't have the time. I don't use it at work.', subject: function
# ------------------------------------
# Comment: 'Version control. Documentation in some specific topics (js extensions, installation and packaging of nb extensions, nbconvert,...)', subject: function
# ------------------------------------
# Comment: 'Support for multiple kernels (especially other languages) is super. Getting it to work is still buggy. The Conda distribution is getting better and better.', subject: performance
# ------------------------------------
# Comment: 'IMO Jupyter is still publication tool rather then programming tool.  (Databricks notebooks look better).  I would prefer way how to better roll up code.', subject: function
# ------------------------------------
# Comment: 'Debugging and refactoring ', subject: function
# ------------------------------------
# Comment: 'A few very minor things cause some issues.  If I could auto-add a title when I create the notebook, or if I could mandate being prompted for one, that would be nice.  Additionally, since I am often developing libraries with C components which can't be reloaded (i.e., yt), it can be cumbersome to do repeated, rapid testing in the notebook.  (I haven't yet upgraded to the new version that has this.)  One last thing would be easier integration of modules for things like storing of notebooks (i.e., bookstore) into a given profile.', subject: function
# ------------------------------------
# Comment: 'A console is usually faster for what I need', subject: design
# ------------------------------------
# Comment: 'It doesn't make coffee', subject: function
# ------------------------------------
# Comment: 'I spend most of my time doing library/application development, and mostly don't need to save records of my work. I use notebooks as scratch areas and one-off things.', subject: function
# ------------------------------------
# Comment: 'No need to use more often.', subject: function
# ------------------------------------
# Comment: 'Forced vertical follow of everything ', subject: function
# ------------------------------------
# Comment: 'Nothing. ', subject: function
# ------------------------------------
# Comment: '- full(er) latex support including cross references for figs, eqns, etc.  - a pure text format for version control / diffs and to allow working from text editor (I strongly dislike working in browser) - ability to output to PDF or a nice printable format - something like nbviewer but allowing execution of code (or like jupyterhub but without manual uploading) - better default styling or easier customization - better widget (animations) support', subject: function
# ------------------------------------
# Comment: 'The biggest thing I miss when using Jupyter is code completion. The addition of an intellisense-like code completion add-on would be a massive step forward. I'm constantly working in several languages so it's hard to keep all of the syntax for various packages in my brain at all times. I love python, love Jupyter, but the lack of code completion is a very glaring deficit at times. ', subject: function
# ------------------------------------
# Comment: 'Javascript, D3 support', subject: performance
# ------------------------------------
# Comment: 'Nothing, the ability to combine data analysis and reporting (to .pdf) in a single document is perfect.', subject: function
# ------------------------------------
# Comment: 'It's really good for annotated code and analysis, but it is not the best if all I want is to take regular notes. I understand that's not its main purpose and I'm suggesting it should be. ', subject: function
# ------------------------------------
# Comment: '- I wish I could make them wider on my 2K screen - every notebook opens a Python icon in the OSX dock', subject: function
# ------------------------------------
# Comment: 'I only very recently figured out how to save Jupyter Notebooks in different places (I navigate to my working directory before typing ipython notebook in the command line). Not having flexibility was a major *perceived* hinderance and could be a good thing to address in the documentation for newbies??', subject: function
# ------------------------------------
# Comment: 'Nothing, because I use Jupyter Notebook for calculos and notes. ', subject: function
# ------------------------------------
# Comment: 'more emacs bindings or more shortcuts that are intuitive', subject: function
# ------------------------------------
# Comment: 'Need search/find (4.1 when available) Need diff tool for Notebooks ', subject: function
# ------------------------------------
# Comment: 'corporate limitations on work projects, laziness on my part on home projects', subject: performance
# ------------------------------------
# Comment: 'lack of diffing and merge tool. (e.g. nbdiff for previous versions of jupyter)', subject: function
# ------------------------------------
# Comment: 'Its confusing to run selected portion of code esp when i change something in the function definition. ', subject: function
# ------------------------------------
# Comment: 'I use it for hobby projects and only rarely at work. For scientific hobby prokects I use it extensively.', subject: performance
# ------------------------------------
# Comment: 'I use it extensively for hobby projects and almost never at work.', subject: performance
# ------------------------------------
# Comment: 'Colleagues using Matlab', subject: design
# ------------------------------------
# Comment: 'It's a bit of a pain to start and stop it. I typically work on different projects in different folders. I bring up a command prompt, cd to the right place, start jupyter, then visit with my browser. Then I need to remember to go back and kill it when I am done. Yes, I could run only one up at my home folder and leave it running all the time. I hate clicking through a giant folder tree to get where I need to be...', subject: function
# ------------------------------------
# Comment: ' ', subject: function
# ------------------------------------
# Comment: 'Notebooks encourage sloppy and non linear programming.', subject: performance
# ------------------------------------
# Comment: 'Still developing my workflow', subject: performance
# ------------------------------------
# Comment: 'Lack of fully-fledged support for authoring.  Compare to the knitr / Sweave model that is fully integrated into the RStudio editor, with support for authoring publication-ready journal pdfs (code chunk options, caching, inline code blocks, tight integration with templates for LaTeX, html, html5-slideshows, etc).  ', subject: performance
# ------------------------------------
# Comment: 'Advances text editing features', subject: function
# ------------------------------------
# Comment: 'Lack of file management in dashboard, meaning sorting by creation and modification times.', subject: performance
# ------------------------------------
# Comment: 'I don't know if it's some kind of special keystrokes, or mouse gestures, but it often changes modes for the current line, and I've got to manually change them back.', subject: function
# ------------------------------------
# Comment: 'jupyter rocks! maybe full text search?', subject: function
# ------------------------------------
# Comment: 'I prefer to work in the terminal. Sometimes I pull it up because I need better multiline editing. Rarely I will use it to author a notebook for external consumption (not because it isn't good for that, but just because I don't really need that that often). ', subject: function
# ------------------------------------
# Comment: 'I use Jupyter Notebooks for education and it is often difficult to get a quick and simple setup that all my students can use. It can take me several days to figure out how to deploy JupyterHub which takes away time from actually preparing material.', subject: function
# ------------------------------------
# Comment: 'Much of my work involves collaborating on development and maintenance of large existing applications.', subject: performance
# ------------------------------------
# Comment: 'Being able to download files generated inside a cell in the output.   Uploading a file to the filesystem from a notebook cell.', subject: function
# ------------------------------------
# Comment: 'Interactive visualisatikn of images, plots etc', subject: function
# ------------------------------------
# Comment: 'As a 'development' environment - as a notebook for analysis - it becomes 'difficult' after 15-20 cells.  By difficult, I mean following branches made - eg a diversion to check some calculation in a few cells - even with headings before and after - could be easier to scroll back to or find.  Some form of outlining (or block folding) would be great.', subject: function
# ------------------------------------
# Comment: 'When I need to use Python + Pandas to analyse data (I am a researcher). Obviously, this depends on the task I am currently working on. In any event, I am using Jupyter notebook more these days.', subject: function
# ------------------------------------
# Comment: 'Having to start/stop the server and kernels, having `.ipynb_checkpoints` directories everywhere', subject: time
# ------------------------------------
# Comment: 'Combining code and output in a single file makes it hard to integrate correctly with version control.', subject: function
# ------------------------------------
# Comment: 'The inability to easily print results as they are seen on the notebook. Especially for my students, having to install LaTex or print from an HTML file is far too difficult just to print out what looks so nice on the screen. In addition, the LaTex looks nothing like the original (with good reason), and this makes it much harder to get what I see into my hand.', subject: function
# ------------------------------------
# Comment: 'Integration in version control (git). ', subject: function
# ------------------------------------
# Comment: 'not easy to turn notebook into python modules to make code reusable', subject: function
# ------------------------------------
# Comment: 'Lack of ability to select multiple cells, copy cells between notebooks. Terrible documentation, particularly of interactive widgets.', subject: function
# ------------------------------------
# Comment: 'I use whenever I need to and when it's the best tool for the job. Not because there's something wrong with it. ', subject: function
# ------------------------------------
# Comment: 'Easy integration with git', subject: function
# ------------------------------------
# Comment: '1. For advanced terminal users, the lack of full emacs (or vi I guess) editing modes is annoying. Maybe it is just that the IPython terminal is too awesome already!  2. Version controlling ipynb files is annoying (but possible and I do it for some notebooks).', subject: function
# ------------------------------------
# Comment: 'I would like a better way to export to different report formats.  For instance, RStudio has a great way to "Create Report" which opens R markdown file that is pre-loaded with defaults for MS Word, HTML, etc.  Even after trying nbconvert I am not too satisfied with this aspect of Jupyter.', subject: function
# ------------------------------------
# Comment: 'Time!!', subject: time
# ------------------------------------
# Comment: 'Difficulty in github synching', subject: function
# ------------------------------------
# Comment: 'Live multiuser editing', subject: function
# ------------------------------------
# Comment: 'ability to script in the notebook so I don't have to have a terminal open for editing standalone code  it would be amazing if a text file could be opened and edited in a cell.  the other problem is absence of something like vim keybindings. The notebook sucks as a text editor.   If there was a vim mode w .vimrc type customization, I'd be in heaven and would likely never not code in jupyter.', subject: function
# ------------------------------------
# Comment: 'The integration of interactive components in the notebook.', subject: function
# ------------------------------------
# Comment: 'Editing files with large amounts of code is still best done in a text editor, though progress has been made on that front.', subject: design
# ------------------------------------
# Comment: 'Shortcut bindings. I'm most productive in vim, the shortcuts in the notebook just don't feel as fluid. Probably isn't a problem that's solvable, but someone might have a nice solution.', subject: function
# ------------------------------------
# Comment: '1. Difficulties diffing notebooks in version control.  2. Interface issues on mobile devices 3. Slide show usage is still tricky', subject: function
# ------------------------------------
# Comment: 'I would like a way to connect an ipython terminal to the same kernel that backs the notebook.  Sometimes I want to test code before putting it in a cell and other times I want to build up code incrementally, inspecting the results.   A terminal that opened at the bottom of the screen would be nice. (maybe split the space vertically with the documentation browser) ', subject: function
# ------------------------------------
# Comment: 'I prefer running R in Emacs.', subject: design
# ------------------------------------
# Comment: 'Recently appointed CTO, so much of my time is currently taken up with strategic matters', subject: time
# ------------------------------------
# Comment: 'The only thing I don't use it for is for writing scripts and when I don't need plots, which is when I use Sublime.  It is used in prototyping those scripts though.', subject: function
# ------------------------------------
# Comment: 'Missing code editor. I often find myself going back to a text editor and copy-paste code from and to jupyther', subject: function
# ------------------------------------
# Comment: 'No smarter way of storing notes/no obvious hyracki ', subject: function
# ------------------------------------
# Comment: 'Primarily use R, Rstudio is better for R.', subject: function
# ------------------------------------
# Comment: '- Difficulty in maintaining emacs-like editing capabilities  ', subject: design
# ------------------------------------
# Comment: '* a "clear and run all" button to get rid of variable persistence (possible with Kernel > Clear all then run but that's more clicks) * a IPython notebook .app -- it'd be really nice to double click on a notebook and have it open', subject: function
# ------------------------------------
# Comment: 'maybe the interface becomes slow if the notebook is too large: entire sections of the notebook could be collapsable so that collapsed sections are not rendered and the notebook stays fully responsive. ', subject: function
# ------------------------------------
# Comment: 'No easy "slide making" button. Hard to turn notebook into a package or library of "run often" code', subject: function
# ------------------------------------
# Comment: 'Nothing, it is a joy and I use it whenever I can.', subject: function
# ------------------------------------
# Comment: '1. Easy drag and drop for reorganizing cells 2. Good version control - the json ipynb structure and cell number are distractions that prevents user from seeing what code actually changed  3. table of content  4. easy collapse of code / output cells  5. saving python data objects - we need a .Rda / .Rsession / .Rhistory file equivalent in IPython. (sorry this may be too much to ask) 5. Jupyter notebook should allow people to write scripts to control table of content, easy collapsing of code / output cells and the CSS style easily 6. Syntax check, Pep8, pylint, pyflake  7. automatic line wrapping for long lines! Lines longer than 80 characters should be wrapped if the user enables this feature. ', subject: function
# ------------------------------------
# Comment: 'Its hard to navigate long notebooks. ', subject: function
# ------------------------------------
# Comment: 'Easier version control would be great. I tend to have a bunch of copies of notebooks with different dates, which gets cumbersome. I also would like some tools to filter the directory interface and remove files that cannot be opened by jupyter. ', subject: function
# ------------------------------------
# Comment: 'Inertia with other tools. ', subject: function
# ------------------------------------
# Comment: 'The fact that sometimes I need to scroll back and forth a lot between two cells. It would be great if they're was an option to set a cell layout, e. g. two columns of just the super comments in markdown would be great to have ', subject: function
# ------------------------------------
# Comment: 'When gigantic debug log message output crashes my browser. ', subject: function
# ------------------------------------
# Comment: 'Installing and working with Jupyter on Windows is cumbersome. The built-in web-based text editor is not as powerful as my everyday desktop text editor. ', subject: design
# ------------------------------------
# Comment: 'UI sucks', subject: function
# ------------------------------------
# Comment: 'It has to be served. I want ipython notebooks to work when I click the file in file explorer', subject: function
# ------------------------------------
# Comment: 'No collapsible cells / sections', subject: function
# ------------------------------------
# Comment: 'The lack of facilities for code re-use. I know there are hacks for importing between notebooks and the like but it still doesn't beat a text editor and DVCS when I want to make something that I'll import or make available on GitHub. My notebooks tend to get messy and out of order. Maybe I need to figure out a better workflow but I often feel a traditional console (i.e. qtconsole) is better (along with the aforementioned editor or IDE).', subject: design
# ------------------------------------
# Comment: 'I wish there was a way to keep a change log of a notebook', subject: function
# ------------------------------------
# Comment: 'Lack of integrated collaboration. Lack of blogging platform based on notebooks.', subject: time
# ------------------------------------
# Comment: 'I mostly use IPython, not the notebook feature, so this is fine as is.', subject: function
# ------------------------------------
# Comment: 'I prefer vi for significant editing.', subject: function
# ------------------------------------
# Comment: 'Less than optimal startup friction; Some issues with keeping track of installed packages.  Some issues with reproducibility (changes to cells can be hard to track while working).', subject: function
# ------------------------------------
# Comment: 'Notebooks tend to get big and messy when used as a scratch pad. Auto generated table of contents would help, as would more options for organizing sections and cells. ', subject: function
# ------------------------------------
# Comment: 'Interactive debugging is too difficult.  Setting breakpoints by clicking line number and then running in debug mode and having a nice way to inspect memory like Pycharm would be filth!', subject: function
# ------------------------------------
# Comment: '- Inability to search across multiple notebooks (e.g., when using as a daily lab notebook) - Hard to separate important from less important stuff when using as a lab notebook', subject: function
# ------------------------------------
# Comment: 'Comprehensive and reliable undo Editing Notebook structure (move many cells at once) Structure editing, hiding subsections', subject: function
# ------------------------------------
# Comment: 'needs a dedicated cell that behaves like a shell', subject: function
# ------------------------------------
# Comment: 'It'd be nice if it could be an even better format for *doing* math, not just writing it up. Not sure exactly what that'd mean, though.  "Graduating" notebook code to in-a-package code is also not as seamless as it might be. If the code editor part had vim bindings and other stuff that made it good enough to be a full time editor, that'd be a huge step.', subject: function
# ------------------------------------
# Comment: 'Better head switch. I m using different machines to work on the same server . I often loose previous output', subject: function
# ------------------------------------
# Comment: 'integration with editor to get linting, multiple selections.   an inspector panel', subject: design
# ------------------------------------
# Comment: 'Version control. I find it unstable due to the rapid pace of development, it's hard to keep track.', subject: function
# ------------------------------------
# Comment: 'Installation is hard, so it's hard to spread the gospel.', subject: performance
# ------------------------------------
# Comment: 'It can't integrate several languages within the same notebook. E.g. Some paragraphs with Scala, some others with SQL, etc...', subject: function
# ------------------------------------
# Comment: 'Better native SQL support would mean I wouldn't need to switch to an external tool as much to write ad hoc SQL queries. ', subject: performance
# ------------------------------------
# Comment: 'it would be nice if they had more tools to edit the code in the cell, for example, comment / uncomment a selected area code', subject: function
# ------------------------------------
# Comment: 'Need of more libraries on geologic and geophysical data processing in python. ', subject: function
# ------------------------------------
# Comment: 'Lack of 3D plotting capabilities ', subject: function
# ------------------------------------
# Comment: 'I'm too attached to emacs shortcuts. I haven't tried using emacs-ipython, but soon...', subject: function
# ------------------------------------
# Comment: 'At times I need to use other work environments (e.g. Atom) when I need other tools, e.g. non-exploratory work.', subject: performance
# ------------------------------------
# Comment: 'It is not vim, and when I make a booboo resulting in an infinite loop, I can't   but have to reach for the Interrupt button in the interface.', subject: function
# ------------------------------------
# Comment: 'I don't fully understand it yet.  I understand what it does and am blown away by little tricks and magic commands.  But coding is my day job and this still feels like a weird way to code.  I'd also like to use it more in teaching kids Python, but I need something like http://trinket.io/ for notebooks.  Hosting it myself is too much work.', subject: function
# ------------------------------------
# Comment: '1. Speed for larger files jupyter is slow. 2. Trouble with integration with git. 3. Export to LaTeX lacks support for Polish language. I have to tinker with tex file in order to compile it. 4. Creating slides is not very intuitive. 5. Cells grouping only appeared in the recent beta. 6. If I delete a cell, the content is lost forever - it makes work very exiting and dangerous. 7. Drag and drop for cells and group of cells would be nice. ', subject: performance
# ------------------------------------
# Comment: '- cumbersome cell manipulation - support for versioning', subject: function
# ------------------------------------
# Comment: 'Having an easiest to connect to distant servers through ssh tunneling / issue with some js call with proxies', subject: function
# ------------------------------------
# Comment: 'Ease of installation greater language support.', subject: performance
# ------------------------------------
# Comment: 'legacy!', subject: performance
# ------------------------------------
# Comment: 'better debugging for variables', subject: function
# ------------------------------------
# Comment: '1. Sometimes it gets very large. Feature of multiple files would be great for developers. 2. Multiple screens e.g. screen divided across 4 files.', subject: function
# ------------------------------------
# Comment: 'Sharing code with people who don't use the notebook.  Editing features of eg. Sublime/Emacs.', subject: function
# ------------------------------------
# Comment: 'I use it for general purpose programming and explorarory stats but not full blow stats tical modelling. Statistical software offers convenience but lacks flexibility. Eventually we could build a convenience in but it would take a while', subject: performance
# ------------------------------------
# Comment: 'Fiddly version control integration ', subject: function
# ------------------------------------
# Comment: 'keyboard shortcuts like vim', subject: design
# ------------------------------------
# Comment: 'On a daily basis my work tends to be quite heavy in computations (large Theano models, but not necessarily Deep-Learning related) which do not seem to work well with notebooks; my machine seem to struggle a bit more when I am working with such models in a notebook and I naively assumed there was a overhead with notebooks.  I am using it extensively though for either quick prototypes (like data explorations and snippets) or to have a polished render of my work.', subject: performance
# ------------------------------------
# Comment: 'Seems a little unnatural to me, but that is probably because I am not sure how it works.', subject: function
# ------------------------------------
# Comment: 'supporting Perl would be handy', subject: function
# ------------------------------------
# Comment: 'Rendering with MathJax is very slow; nbconvert for LaTeX sometimes is broken; the absense of tools for nbdiff and nbmerge.', subject: function
# ------------------------------------
# Comment: 'Real time multi peer collaboration (a'la Google Docs).', subject: time
# ------------------------------------
# Comment: 'Seamless integration to other languages out of the box. Better version controlling for sharing work with peers. ', subject: performance
# ------------------------------------
# Comment: 'Better/simple exporting tools to pdf. I use a lot of math in my notebook, and I usually need to share a pdf copy with my team, who do not use Jupyter', subject: function
# ------------------------------------
# Comment: 'I do a some Django development that requires me to use Eclipse. I wish the text editor had better python coding tools like auto-complete using tab.', subject: function
# ------------------------------------
# Comment: 'The tasks that I like to do in Notebook are a more or less monthly thing. I mainly use it as a learning tool.   I use Emacs for most programming tasks. ', subject: function
# ------------------------------------
# Comment: 'time ? No I really use it every day at work. (I can't use it much more!)', subject: time
# ------------------------------------
# Comment: 'other work that needs to be done ;-)', subject: performance
# ------------------------------------
# ...
# ------------------------------------
# Comment: 'I dislike the interface.', subject: function
# ------------------------------------
# Comment: 'I don't use python very much, and support for other kernels (e.g., scala) could be better.', subject: function
# ------------------------------------
# Comment: 'Debugging functionality, version control for notebooks, UI', subject: function
# ------------------------------------
# Comment: '- Lack of diff/merge capability  Other areas are largely dealing with text generation: - I *think* ways to split/link notebooks would help with looonng and spaghetti-like notebooks (but I'm not sure)  - I'm just not a fan of browser-based editing, but this is not a top priority.  - I'm a huge fan of org-mode/latex and like the "automatic" numbering and cross-reference abilities.', subject: function
# ------------------------------------
# Comment: 'remembering how to get it setup', subject: function
# ------------------------------------
# Comment: 'Inability to easily publish to common platforms like wordpress that aren't based around websites generated by code. Still a bit of a hassle to get a remote notebook running well just for personal use (e.g., I don't want to have to generate hashes etc, but for now SSH tunneling is working fine for me). Some less-sexy features missing like copy/pasting multiple cells at once etc.', subject: function
# ------------------------------------
# Comment: 'Nothing, really. It works great.', subject: function
# ------------------------------------
# Comment: 'Text editing capabilities within the notebook cells is very limited. I am currently following these projects in the hopes of a viable workaround: https://github.com/jupyter/atom-notebook https://github.com/Cacodaimon/GhostText-for-Atom', subject: function
# ------------------------------------
# Comment: 'Find a way to manage proliferation. A nice way to order them.', subject: function
# ------------------------------------
# Comment: 'lack of debug support when writing huge pieces of code such as loops, functions...', subject: function
# ------------------------------------
# Comment: 'It can't be used without a browser.', subject: design
# ------------------------------------
# Comment: 'I tried Jupyter for making some lecture slides for teaching statistical methods in Python. My main grievances were the lack of more advanced (code-) editor features like incremental searching and an outline view for better navigation (during presentation and writing). I am aware of plugins, which I unfortunately could not to get work seamlessly (in Anaconda).   One thing which lets me prefer Spyder for my daily work is its context sensitive help, where or each command you type in a separate window a nicely typeset help text appears automatically. When using Scipy extensively, this is a real help.   For casual users like me, the number of key strokes and commands one needs to remember for efficient work is a burden. Extended tool bars (especially for Markdown) could flatten the learning curve quite a bit.   Furthermore, typesetting advanced math is a bit cumbersome (especially when looking for typos which prevent rendering, integrating your own macros, equation cross referencing, etc). A better integration could replace LaTeX for many documentation tasks (as in technical reports).', subject: function
# ------------------------------------
# Comment: 'Having to work with it mainly from either the command line or from the Anaconda launcher. I would prefer to have a native Mac app that will open and manage Jupyter notebooks from anywhere on my machine. With the command line for example I have to first navigate to the directory where my notebooks are located -- I have a lot of directories and I don't want to have to start up a new notebook client for every place where they are stored. ', subject: function
# ------------------------------------
# Comment: 'Notebook offers only global space. It is like single python module. And most of my code consists of several modules', subject: function
# ------------------------------------
# Comment: 'For scripts that run in a pipeline, would like to parameterize them using command line arguments. Don't know if it's possible.', subject: function
# ------------------------------------
# Comment: 'The difficulty of setting it up for a multiuser classroom environment. The difficulty in setting up a widget framework for interactive demos for students', subject: function
# ------------------------------------
# Comment: 'missing search and replace collaborators not using it', subject: function
# ------------------------------------
# Comment: 'vim shortcuts use emacs as frontend (incl plots and interactive widgets)', subject: design
# ------------------------------------
# Comment: 'I write libraries which require a full-fledged IDE.', subject: function
# ------------------------------------
# Comment: 'Text editing capabilities within the notebook cells is very limited. I am currently following these projects in the hopes of a viable workaround: https://github.com/jupyter/atom-notebook https://github.com/Cacodaimon/GhostText-for-Atom', subject: function
# ------------------------------------
# Comment: 'Inability to easily navigate within modules/structured code directories, so that I can develop my code simultaneously as a package/module and within a notebook. Prototyping in the notebook is great, but then making sure everything works appropriately when outside of the notebook environment is more difficult without a lot more infrastructure. Furthermore, once it is ported to an external module, its essentially impossible to either bring the code back into the notebook efficiently (i.e., not just copying and pasting into cells) and or to maintain a coherent version control stream for the changes then made in the notebook. So currently software development in a notebook to external module is a 1-way street, and not a particularly easy one to navigate.   Also, inconsistency in relative import statements make developing software packages in a notebook/module. Given the portable nature of the notebook, it's nice to be able to work from the same source files on a variety of computers. But absolute paths can't be used across machines (unless they follow the same convention) and its not clear how one would specify the absolute path relative to the location of the notebook server and vs. notebook itself.  Editing documentation in the notebook (especially with executable examples) would make it easier to jump between source code and explicit documentation. Linking a particular cell out to a particular docstring for a particular function/class/method would be great.', subject: function
# ------------------------------------
# Comment: 'Unfamiliarity with Python.', subject: function
# ------------------------------------
# Comment: 'more full featured ide feature (find replace, refactor, code folding/hiding, etc)    reusing code easily between notebooks', subject: function
# ------------------------------------
# Comment: 'In my university, Matlab is the standard. So often I have to use that ... ', subject: design
# ------------------------------------
# Comment: 'Deploying a secure shared notebook server to facilitate easy sharing of notebooks with less computer-savvy colleagues.', subject: function
# ------------------------------------
# Comment: 'Collaborators that I haven't been able to indoctrinate yet.', subject: function
# ------------------------------------
# Comment: 'More and clear documentation would be nice.', subject: function
# ------------------------------------
# Comment: 'Version control / diffing version control between notebooks. ', subject: function
# ------------------------------------
# Comment: 'Support for multiple programming kernels in the same notebook. ', subject: performance
# ------------------------------------
# Comment: 'Better editor in browser; better dashboard ---need to have a real file/folder manager; multi-file notebooks (to contain related files); better pdb (command completion, history)', subject: function
# ------------------------------------
# Comment: 'The fact that I run windows and so don't have a reliable bash kernel (I've used bash_metakernel with cygwin but it's not so reliable - prompt gets out of sync).  In fact I've promoted using Jupyter for documenting/demonstrating command-line stuff and I'd be ready to go if *I ran linux all the time*. I don't for Corporate reasons.  Although my laptop has 32G it overheats and the fan is noisy ... so I tend not to run under VirtualBox as much as I'd like.  Hope all that makes sense !!', subject: function
# ------------------------------------
# Comment: 'Automatic word completion', subject: function
# ------------------------------------
# Comment: 'Complicated startup of the server (especially when my notebooks are in a directory that is not the standard base notebook dricetory). Mathematica, in contrast,  just starts up and can use a notebook from everywhere.', subject: function
# ------------------------------------
# Comment: '* The "impedance mismatch" between Jupyter Notebooks and version control systems like git.  * The lack of high-level document refactoring, e.g. moving around entire sections.  (The Calico Tools plugin makes this more bearable.)', subject: function
# ------------------------------------
# Comment: 'Lack of variable persistence', subject: performance
# ------------------------------------
# Comment: 'Miss basic functionality that was easy to access when working with ipynb notebooks in Enthought Canopy', subject: function
# ------------------------------------
# Comment: 'Just other duties,  but I'm planning to start use it on a daily basis', subject: function
# ------------------------------------
# Comment: 'It's actually my main tool, so not a whole lot to do to have it used more', subject: function
# ------------------------------------
# Comment: 'Text editing. I often fall back to other options like Sublime Text, wishing that Jupyter had some of that functionality.', subject: function
# ------------------------------------
# Comment: 'I use it extensively for python, no issues. For Julia, R, and Ruby, though, things are still a bit glitchy.', subject: function
# ------------------------------------
# Comment: '-Would like to have a code editor and terminal in the same window as the notebook cells', subject: function
# ------------------------------------
# Comment: 'Inexpensive, remotely hosted options for running courses that use jupyter notebooks.', subject: function
# ------------------------------------
# Comment: 'Ease of version control with gift hub, sharing with non-technical users, collapsible input boxes to make it easier for non-technical personnel to understand, syntax highlighting in JavaScript cells, easy debugging, ease of implementing in server side CRON jobs etc.   ', subject: function
# ------------------------------------
# Comment: '- Multi-panel user interface similar to spyder/matlab with embedded ipython console.  - Free-form cell editing similar to spyder/matlab (e.g. to move many cells at the same time)  - Dead easy debugging support  - Maybe support for profiling code', subject: function
# ------------------------------------
# Comment: 'The UI takes a lot of vertical space, and not a lot of horizontal one (Most Displays are in the 16:9 aspect ratio ). Multiple input columns (or input left output right) and a "minimap" would be nice.   Data import into Python  Data exploration (bokeh/matplotlib is just not as interactive compared to matlab plot interface)', subject: function
# ------------------------------------
# Comment: 'Integration with Git, or at least some documentation on ho best to use version control with Jupyter.', subject: function
# ------------------------------------
# Comment: 'Work schedule. Nothing to do with Jupyter itself.', subject: function
# ------------------------------------
# Comment: 'Ipython on command line is more familiar. ', subject: function
# ------------------------------------
# Comment: 'The acceptance of it as the main tool for exploratory data analysis by colleagues who are less technical and continue to use excel and tableau. They are deterred by learning curve of Python and its libraries - which isn't really Jupypters fault.  ', subject: function
# ------------------------------------
# Comment: 'Not enough people use it around me.', subject: function
# ------------------------------------
# Comment: 'Searching in the notebooks is a pain because files can not just be opened through a dedicated viewer (on desktop os), which makes looking for that specific graph from 2 months ago hard. (Ofentimes just seeing it is enough to know which one I was searching for)', subject: design
# ------------------------------------
# Comment: 'difficult to manage code cells, rearrange them', subject: function
# ------------------------------------
# Comment: 'Crappy editing experience. After being used to working exclusively in Vim/Emacs, developing in a text area in a browser just doesn't feel right.', subject: design
# ------------------------------------
# Comment: 'Exporting notebooks to other formats, such as pdf, is not working for me.  BTW I have an Anaconda install of Python 2.7 running on Windows 10.', subject: function
# ------------------------------------
# Comment: 'Slow. Doesn't handle large datasets well - crashes, often have to rerun from the top. ', subject: function
# ------------------------------------
# Comment: 'we need a way to hide the code to create a better document like in Zeppelin', subject: function
# ------------------------------------
# Comment: 'mostly support for collaboration: multi-user server, difficult diff of notebooks', subject: function
# ------------------------------------
# Comment: 'Difficulty sharing results with collaborators who don't use Jupyter. HTML output works alright, but since my notebooks are math heavy they take quite a long time to load for collaborators.', subject: function
# ------------------------------------
# Comment: 'No strong complaints at the moment.', subject: function
# ------------------------------------
# Comment: 'Text-block weakness: - absence of LaTeX-like cross-referencing and automatic (section) numbering facility  Code-block weaknesses: - no way to "tangle" code blocks to make pure source code files (afaik) - no easy, clear or consistent way to automatically break lines at a specified number of char's - no code folding - difficulty in using Javascript to do special visualizations, for example with D3.js', subject: function
# ------------------------------------
# Comment: 'Would be great to have more advanced editor features for the cells. Would be great to have an easy way to switch between scripts and interactive sessions (a bit like in RStudio where you can execute parts of a script).', subject: function
# ------------------------------------
# Comment: '- Not very handy to inspect large dataframes (spyder variable explorer is a better tool for that purpose) - Cannot use git to do version control. - I mostly del with a lots of files of code and Jupyter is just form interactive exploration or demos', subject: function
# ------------------------------------
# Comment: 'I still use the Qt backend sometimes with matplotlib since I find the notebook backend to be awkward to use sometimes.', subject: function
# ------------------------------------
# Comment: 'Having an AWK specific version would be useful instead of having to use the bash support.  https://github.com/tonycasanova/Jupyter/blob/master/AWK_BasicExample_1_A.ipynb', subject: function
# ------------------------------------
# Comment: 'Single window of browser Lack of integration with github Lots of my work borders on BI, for which BI tools are really better suited, e.g. drill down into datasets ', subject: performance
# ------------------------------------
# Comment: 'Right tool for the job.', subject: function
# ------------------------------------
