# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

from subprocess import check_output
print(check_output(["ls", "../Survey_Classification"]).decode("utf8"))
# Out:
# 1-s2.0-S2090447914000550-gr1.jpg
# 1-s2.0-S2090447914000550-main.pdf
# CleanSurvey.csv
# Survey.csv
# Survey_Classification_v1.ipynb

# %%
df=pd.read_csv("../Survey_Classification/Survey.csv")

# %%
df.head()
# Out:
#           Time Started       Date Submitted    Status  \
# 0  2015-12-21 22:21:47  2015-12-21 22:21:51   Partial
# 1  2015-12-22 00:03:36  2015-12-22 00:26:01  Complete
# 2  2015-12-22 00:17:49  2015-12-22 00:17:49   Partial
# 3  2015-12-22 00:22:07  2015-12-22 00:24:02   Partial
# 4  2015-12-22 00:41:40  2015-12-22 00:42:09   Partial
#
#   How often do you use Jupyter Notebook?  \
# 0                                    NaN
# 1                                  Daily
# 2                                    NaN
# 3                                  Daily
# 4                                 Weekly
#
#   What, if anything, hinders you from making Jupyter Notebook an even more regular part of your workflow?  \
# 0                                                NaN
# 1  Ways to hide helper function definitions (or e...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Roughly how long have you been using Jupyter Notebook?  \
# 0                                                NaN
# 1                                 Less than one year
# 2                                                NaN
# 3                                   One year or more
# 4                                   One year or more
#
#   Tool / Application #1:What tools and applications, if any, would you like to see more tightly integrated with Jupyter Notebook?      \
# 0                                                NaN
# 1                                         sqlalchemy
# 2                                                NaN
# 3                 version control on notebooks (git)
# 4                                                NaN
#
#   Tool / Application #2:What tools and applications, if any, would you like to see more tightly integrated with Jupyter Notebook?      \
# 0                                                NaN
# 1  bokeh (or other JS/interactive plotting packages)
# 2                                                NaN
# 3                              publishing dashboards
# 4                                                NaN
#
#   Tool / Application #3:What tools and applications, if any, would you like to see more tightly integrated with Jupyter Notebook?      \
# 0                                                NaN
# 1  diff tool for changes in src (primarily for gi...
# 2                                                NaN
# 3                                 dockerised kernels
# 4                                                NaN
#
#   How do you run the Jupyter Notebook?  \
# 0                                  NaN
# 1          As a standalone application
# 2                                  NaN
# 3                  Through Jupyter Hub
# 4          As a standalone application
#
#                                                                                                                                                   ...                                                                                                                                                   \
# 0                                                                                                                                                 ...
# 1                                                                                                                                                 ...
# 2                                                                                                                                                 ...
# 3                                                                                                                                                 ...
# 4                                                                                                                                                 ...
#
#   Enhancement #2:Thinking back to when you first started using Jupyter Notebook, what enhancements would have made your initial experience better?  \
# 0                                                NaN
# 1  easier callbacks with ipywidgets / ways to get...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Enhancement #3:Thinking back to when you first started using Jupyter Notebook, what enhancements would have made your initial experience better?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Select all the words that best describe Jupyter Notebook.  \
# 0                                                NaN
# 1                        comfortable;intuitive;quick
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Other word(s)::Select all the words that best describe Jupyter Notebook.  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   What is your primary role when using Jupyter Notebook (e.g., student, astrophysicist, financial modeler, business manager, etc.)?  \
# 0                                                NaN
# 1          grad student (computational astrophysics)
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   How many years have you been in this role?   \
# 0                                         NaN
# 1                                      1 year
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#   Industry #1:What industries does your role and analytical work support (e.g., Journalism, IT, etc.)?  \
# 0                                                NaN
# 1                                   academic science
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Industry #2:What industries does your role and analytical work support (e.g., Journalism, IT, etc.)?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Industry #3:What industries does your role and analytical work support (e.g., Journalism, IT, etc.)?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   How many people typically see and/or interact with the results of your work in Jupyter Notebook? (Consider people who view your notebooks on nbviewer, colleagues who rerun your notebooks, developers who star your notebook repos on GitHub, audiences who see your notebooks as slideshows, etc.)
# 0                                                NaN
# 1                                               Tens
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 37 columns]

# %%
df_s = df.copy()

# %%
df_s = df_s.rename(columns = {'What, if anything, hinders you from making Jupyter Notebook an even more regular part of your workflow?':
                              'Constrains'})

# %%
df_s.head()
# Out:
#           Time Started       Date Submitted    Status  \
# 0  2015-12-21 22:21:47  2015-12-21 22:21:51   Partial
# 1  2015-12-22 00:03:36  2015-12-22 00:26:01  Complete
# 2  2015-12-22 00:17:49  2015-12-22 00:17:49   Partial
# 3  2015-12-22 00:22:07  2015-12-22 00:24:02   Partial
# 4  2015-12-22 00:41:40  2015-12-22 00:42:09   Partial
#
#   How often do you use Jupyter Notebook?  \
# 0                                    NaN
# 1                                  Daily
# 2                                    NaN
# 3                                  Daily
# 4                                 Weekly
#
#                                           Constrains  \
# 0                                                NaN
# 1  Ways to hide helper function definitions (or e...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Roughly how long have you been using Jupyter Notebook?  \
# 0                                                NaN
# 1                                 Less than one year
# 2                                                NaN
# 3                                   One year or more
# 4                                   One year or more
#
#   Tool / Application #1:What tools and applications, if any, would you like to see more tightly integrated with Jupyter Notebook?      \
# 0                                                NaN
# 1                                         sqlalchemy
# 2                                                NaN
# 3                 version control on notebooks (git)
# 4                                                NaN
#
#   Tool / Application #2:What tools and applications, if any, would you like to see more tightly integrated with Jupyter Notebook?      \
# 0                                                NaN
# 1  bokeh (or other JS/interactive plotting packages)
# 2                                                NaN
# 3                              publishing dashboards
# 4                                                NaN
#
#   Tool / Application #3:What tools and applications, if any, would you like to see more tightly integrated with Jupyter Notebook?      \
# 0                                                NaN
# 1  diff tool for changes in src (primarily for gi...
# 2                                                NaN
# 3                                 dockerised kernels
# 4                                                NaN
#
#   How do you run the Jupyter Notebook?  \
# 0                                  NaN
# 1          As a standalone application
# 2                                  NaN
# 3                  Through Jupyter Hub
# 4          As a standalone application
#
#                                                                                                                                                   ...                                                                                                                                                   \
# 0                                                                                                                                                 ...
# 1                                                                                                                                                 ...
# 2                                                                                                                                                 ...
# 3                                                                                                                                                 ...
# 4                                                                                                                                                 ...
#
#   Enhancement #2:Thinking back to when you first started using Jupyter Notebook, what enhancements would have made your initial experience better?  \
# 0                                                NaN
# 1  easier callbacks with ipywidgets / ways to get...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Enhancement #3:Thinking back to when you first started using Jupyter Notebook, what enhancements would have made your initial experience better?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Select all the words that best describe Jupyter Notebook.  \
# 0                                                NaN
# 1                        comfortable;intuitive;quick
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Other word(s)::Select all the words that best describe Jupyter Notebook.  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   What is your primary role when using Jupyter Notebook (e.g., student, astrophysicist, financial modeler, business manager, etc.)?  \
# 0                                                NaN
# 1          grad student (computational astrophysics)
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   How many years have you been in this role?   \
# 0                                         NaN
# 1                                      1 year
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#   Industry #1:What industries does your role and analytical work support (e.g., Journalism, IT, etc.)?  \
# 0                                                NaN
# 1                                   academic science
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Industry #2:What industries does your role and analytical work support (e.g., Journalism, IT, etc.)?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Industry #3:What industries does your role and analytical work support (e.g., Journalism, IT, etc.)?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   How many people typically see and/or interact with the results of your work in Jupyter Notebook? (Consider people who view your notebooks on nbviewer, colleagues who rerun your notebooks, developers who star your notebook repos on GitHub, audiences who see your notebooks as slideshows, etc.)
# 0                                                NaN
# 1                                               Tens
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 37 columns]

# %%
null_list = ['nothing', 'Nothing!', 'Nothing',
             'n/a', 'Nothing.', 'N/A', 'None',
             'none','No further need', 'hh',
             'Nothing so far!','nothing I can think of',' ']

for phrase in null_list:
    df_s.Constrains.replace(phrase, ' ', inplace=True)

# %%
df_s.Constrains.str.lower()
# Out:
# 0                                                     NaN
# 1       ways to hide helper function definitions (or e...
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# 5                                                lazyness
# 6       having to setup a jupyter server in a particul...
# 7       - a standard option of converting the notebook...
# 8       mainly two missing features: 1. collapsable se...
# 9       maybe figure out how to schedule automated exe...
# 10         don't use it to teach all of my courses (yet).
# 11      browser becomes unresponsive when i start a to...
# 12                                real time collaboration
# 13      my coworkers do not use them. keybindings clas...
# 14                                        git integration
# 15      corporate it policy colleagues' lack of knowle...
# 16      it is very easy to do exploratory computing, b...
# 17                                                    NaN
# 18                                                    NaN
# 19                                                    NaN
# 20                                                    NaN
# 21      not too easy to integrate into a git workflow ...
# 22      poor experience opening notebooks in arbitrary...
# 23       ide capabilities: debugging ui, refactorings,...
# 24                   working on notebooks collaboratively
# 25                                                    NaN
# 26      lack of multi-cell copy/paste (until now). dif...
# 27      hub support for windows. better kernel reliabi...
# 28      improved workflow to create reports with it. j...
# 29      mostly, the fact that not many colleagues, col...
#                               ...
# 1676                                                  NaN
# 1677    exporting notebooks to other formats, such as ...
# 1678    slow. doesn't handle large datasets well - cra...
# 1679                                                  NaN
# 1680                                                  NaN
# 1681    we need a way to hide the code to create a bet...
# 1682                                                  NaN
# 1683    mostly support for collaboration: multi-user s...
# 1684                                                  NaN
# 1685                                                  NaN
# 1686    difficulty sharing results with collaborators ...
# 1687                                                  NaN
# 1688                                                  NaN
# 1689                                                  NaN
# 1690                  no strong complaints at the moment.
# 1691    text-block weakness: - absence of latex-like c...
# 1692                                                  NaN
# 1693    would be great to have more advanced editor fe...
# 1694                                                  NaN
# 1695    - not very handy to inspect large dataframes (...
# 1696                                                  NaN
# 1697    i still use the qt backend sometimes with matp...
# 1698                                                  NaN
# 1699                                                  NaN
# 1700                                                  NaN
# 1701    having an awk specific version would be useful...
# 1702    single window of browser lack of integration w...
# 1703                              right tool for the job.
# 1704                                                  NaN
# 1705                                                  NaN
# Name: Constrains, Length: 1706, dtype: object

# %%
df_s.Constrains.str.strip()
# Out:
# 0                                                     NaN
# 1       Ways to hide helper function definitions (or e...
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# 5                                                lazyness
# 6       Having to setup a Jupyter server in a particul...
# 7       - a standard option of converting the notebook...
# 8       Mainly two missing features: 1. Collapsable se...
# 9       Maybe figure out how to schedule automated exe...
# 10         Don't use it to teach all of my courses (yet).
# 11      Browser becomes unresponsive when I start a to...
# 12                                real time collaboration
# 13      My coworkers do not use them. Keybindings clas...
# 14                                        git integration
# 15      Corporate IT policy Colleagues' lack of knowle...
# 16      It is very easy to do exploratory computing, b...
# 17                                                    NaN
# 18                                                    NaN
# 19                                                    NaN
# 20                                                    NaN
# 21      not too easy to integrate into a git workflow ...
# 22      Poor experience opening notebooks in arbitrary...
# 23       IDE capabilities: debugging UI, refactorings,...
# 24                   working on notebooks collaboratively
# 25                                                    NaN
# 26      Lack of multi-cell copy/paste (until now). Dif...
# 27      Hub support for Windows. Better kernel reliabi...
# 28      Improved workflow to create reports with it. J...
# 29      Mostly, the fact that not many colleagues, col...
#                               ...
# 1676                                                  NaN
# 1677    Exporting notebooks to other formats, such as ...
# 1678    Slow. Doesn't handle large datasets well - cra...
# 1679                                                  NaN
# 1680                                                  NaN
# 1681    we need a way to hide the code to create a bet...
# 1682                                                  NaN
# 1683    mostly support for collaboration: multi-user s...
# 1684                                                  NaN
# 1685                                                  NaN
# 1686    Difficulty sharing results with collaborators ...
# 1687                                                  NaN
# 1688                                                  NaN
# 1689                                                  NaN
# 1690                  No strong complaints at the moment.
# 1691    Text-block weakness: - absence of LaTeX-like c...
# 1692                                                  NaN
# 1693    Would be great to have more advanced editor fe...
# 1694                                                  NaN
# 1695    - Not very handy to inspect large dataframes (...
# 1696                                                  NaN
# 1697    I still use the Qt backend sometimes with matp...
# 1698                                                  NaN
# 1699                                                  NaN
# 1700                                                  NaN
# 1701    Having an AWK specific version would be useful...
# 1702    Single window of browser Lack of integration w...
# 1703                              Right tool for the job.
# 1704                                                  NaN
# 1705                                                  NaN
# Name: Constrains, Length: 1706, dtype: object

# %%
df_s.to_csv('CleanSurvey.csv', encoding='utf-8')

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
import nltk
import re

# %%
stopWords = set(stopwords.words("english"))
for text in df_s.Constrains:
    if str(text) != 'nan':
        line = re.sub(r'[^\w]', ' ', str(text))
        words = nltk.word_tokenize(line.decode('utf-8'))
        tagged = nltk.pos_tag(words)
        print [ str(word) for word, tag in tagged if tag in 'NN' and len(word) > 1]
# Out:
# ['function']
# ['lazyness']
# ['server', 'folder', 'location', 'file', 'access', 'folder', 'computer', 'explorer', 'search', 'preview']
# ['option', 'notebook', 'pdf', 'code', 'output', 'integration', 'website', 'sphinx', 'website', 'sort', 'tool', 'format', 'rst', 'rendering', 'output', 'format', 'package', 'pandas', 'notebook', 'html', 'representation', 'representation']
# ['cell', 'selection', 'copy', 'cut', 'paste']
# ['figure', 'execution']
# ['use']
# ['computation', 'integration', 'code']
# ['time', 'collaboration']
# ['clash', 'vimperator']
# ['integration']
# ['policy', 'lack', 'knowledge', 'stack']
# ['quantum', 'computation', 'analysis', 'text', 'simulation', 'analysis', 'notebook', 'step', 'data', 'output', 'step', 'interactivity', 'way', 'program', 'state', 'something', 'scope', 'persistence', 'solution', 'pain', 'point', 'nature', 'Notebook']
# ['look']
# ['experience', 'home', 'tree', 'click', 'file', 'jupyter', 'notebook', 'feature']
# []
# []
# ['Lack', 'multi', 'cell', 'copy', 'paste', 'version', 'control', 'documentation', 'notebook', 'format']
# ['support', 'reliability']
# ['bibtex', 'file', 'reordering']
# ['fact']
# ['Time']
# ['Documentation', 'launch', 'thing']
# ['Lack', 'debugging']
# ['part', 'team', 'management', 'applicability', 'secure', 'definition', 'user']
# ['interact', 'commit']
# ['text', 'editor', 'app', 'hassle', 'console', 'place', 'click', 'opening', 'please']
# []
# ['integration', 'version', 'control', 'cross', 'project', 'search']
# ['pain']
# ['github', 'integration', 'right']
# ['code']
# ['functionnality', 'file', 'serach']
# ['Ability', 'code']
# []
# ['directory', 'struction', 'default', 'output', 'notebook', 'notebook']
# ['editing']
# ['load', 'notebook', 'directory', 'session', 'notebook', 'server', 'notebook', 'Note', 'notebook', 'latter']
# ['Nothing']
# ['college', 'work']
# ['instance']
# ['solution', 'version', 'control', 'ad', 'hoc', 'use', 'something', 'momentum', 'move', 'cursor', 'focus', 'cell', 'top', 'dev', 'jupyter', 'mailing', 'info', 'project']
# ['notebook', 'file', 'code']
# ['Awkwardness', 'use', 'cf', 'desktop', 'cell', 'vs', 'Difficulty', 'majority', 'way', 'repos', 'log', 'repo', 'readme', 'didnt', 'rpy2', 'guidance', 'kernel', 'version', 'development', 'productivity', 'fact']
# ['file', 'browser', 'checkpoint', 'feature', 'state', 'history']
# []
# ['artifact', 'computing']
# ['notebook', 'code', 'ability', 'edit', 'module', 'cell', 'interact']
# ['work', 'half']
# ['environment']
# ['interface', 'document', 'interface', 'software', 'information', 'interaction', 'example', 'editor', 'browser', 'command', 'line', 'etc']
# ['notebook', 'gui', 'browser']
# ['work', 'tool']
# ['integration']
# []
# []
# ['initialization']
# ['plain']
# ['part', 'notebook', 'script', 'notebook', 'production', 'mode']
# ['version', 'control', 'development', 'text', 'editor', 'development', 'browser', 'window']
# ['something', 'excel']
# ['ability', 'hooks', 'functionality', 'point']
# ['Integration', 'version', 'control', 'production', 'code']
# []
# ['lack', 'need', 'command', 'line', 'configuration', 'fact']
# ['checking', 'code', 'ala', 'integration', 'version', 'control', 'editor', 'code']
# ['control', 'git', 'grouping']
# ['beginner', 'programmer']
# ['work', 'group', 'lot', 'format', 'notebook', 'setting']
# ['time', 'use', 'script', 'end']
# ['computing', 'setup', 'workflow', 'version', 'control', 'system', 'language', 'mapping', 'notebook', 'variable', 'cell', 'one']
# ['Challenge', 'language', 'integration', 'lot', 'difficulty']
# []
# ['use']
# ['collaboration', 'memory', 'stress', 'python', 'command', 'line']
# ['work', 'version', 'control', 'line', 'code', 'doesn', 'correspond', 'line', 'notebook', 'file', 'text', 'editor', 'development', 'editor', 'vim', 'emacs', 'text', 'area']
# ['spent', 'time']
# ['Lack', 'project', 'view', 'inter', 'notebook', 'copy', 'pasting', 'code']
# ['complaint', 'lack', 'find', 'text', 'editor', 'style', 'point', 'jupyter', 'code', 'text', 'editor', 'time', 'experience', 'integration', 'bit', 'headache', 'env', 'reconfigure', 'jupyter', 'side', 'translation', 'python', 'py', 'file']
# ['jupyterhub', 'win', 'environment']
# ['tool']
# ['editor', 'vim', 'emacs', 'terminal']
# ['editor', 'editor', 'code', 'server', 'support', 'way', 'conda', 'environment', 'ipython', 'notebook', 'running', 'conda', 'point', 'service', 'something', 'kernel', 'conda', 'environment', 'navigate', 'folder', 'work', 'time']
# ['browser']
# ['emacs']
# ['screen']
# ['convert', 'latex', 'option', 'plug', 'kind', 'moment', 'support']
# ['notebook', 'editor', 'ide']
# ['version', 'control', 'workflow', 'notebook', 'version', 'control']
# ['programming', 'language']
# ['setup', 'code', 'button', 'input', 'code', 'notebook', 'tool', 'bar', 'input']
# ['Collaboration', 'versionning']
# ['fact', 'browser', 'window', 'browser', 'tab', 'default', 'volatility', 'environment', 'overview', 'folder', 'etc']
# ['difficulty', 'code', 'notebook', 'command', 'line', 'code', 'notebook', 'version', 'control', 'git']
# []
# ['time', 'use', 'work']
# ['control', 'installation', 'packaging']
# ['Support', 'distribution']
# ['tool', 'tool', 'way', 'code']
# []
# ['auto', 'title', 'notebook', 'one', 'testing', 'notebook', 'version', 'thing', 'integration', 'profile']
# ['console']
# ['coffee']
# ['time', 'application', 'development', 'work', 'scratch', 'off']
# ['need']
# ['follow', 'everything']
# ['Nothing']
# ['er', 'support', 'cross', 'pure', 'text', 'format', 'version', 'control', 'editor', 'browser', 'ability', 'output', 'format', 'something', 'execution', 'code', 'jupyterhub', 'uploading', 'default', 'customization', 'widget', 'support']
# ['thing', 'completion', 'addition', 'intellisense', 'code', 'completion', 'add', 'step', 'syntax', 'brain', 'lack', 'code', 'completion', 'deficit']
# ['support']
# ['ability', 'analysis', 'reporting', 'document']
# ['code', 'analysis', 'purpose']
# ['notebook', 'icon', 'dock']
# ['directory', 'ipython', 'notebook', 'command', 'line', 'flexibility', 'hinderance', 'thing', 'documentation']
# ['Nothing', 'calculos']
# []
# ['search', 'diff', 'tool']
# ['work', 'part', 'home']
# ['lack', 'diffing', 'merge', 'tool', 'nbdiff', 'jupyter']
# ['portion', 'code', 'esp', 'something', 'function', 'definition']
# ['hobby', 'work', 'hobby']
# ['hobby', 'work']
# []
# ['bit', 'pain', 'command', 'cd', 'place', 'jupyter', 'visit', 'browser', 'home', 'folder', 'time', 'folder', 'tree']
# []
# ['programming']
# ['workflow']
# ['Lack', 'support', 'knitr', 'model', 'editor', 'support', 'publication', 'journal', 'pdfs', 'code', 'chunk', 'code', 'integration', 'html', 'html5', 'etc']
# []
# ['Lack', 'management', 'dashboard', 'meaning', 'sorting', 'creation', 'modification']
# ['kind', 'mouse', 'line']
# ['jupyter', 'text', 'search']
# ['multiline', 'notebook', 'consumption']
# ['education', 'setup', 'time', 'material']
# ['work', 'development', 'maintenance']
# ['cell', 'output', 'file', 'filesystem', 'notebook', 'cell']
# ['visualisatikn']
# ['development', 'environment', 'notebook', 'analysis', 'diversion', 'calculation', 'form', 'block', 'folding']
# ['researcher', 'task', 'event', 'notebook']
# ['server']
# ['code', 'output', 'file', 'version', 'control']
# ['inability', 'notebook', 'print', 'file', 'screen', 'addition', 'nothing', 'reason', 'hand']
# ['Integration', 'version', 'control', 'git']
# ['notebook', 'python', 'code']
# ['Lack', 'ability', 'documentation']
# ['tool', 'job', 'something']
# ['integration', 'git']
# ['lack', 'emacs', 'vi', 'terminal']
# ['way', 'report', 'instance', 'way', 'markdown', 'file', 'aspect']
# ['Time']
# ['Difficulty', 'github', 'synching']
# ['multiuser']
# ['ability', 'notebook', 'open', 'standalone', 'code', 'text', 'file', 'cell', 'problem', 'absence', 'something', 'notebook', 'text', 'editor', 'mode', 'vimrc', 'type', 'customization', 'jupyter']
# ['integration', 'notebook']
# ['code', 'text', 'editor', 'progress', 'front']
# ['vim', 'notebook', 'feel', 'fluid', 'isn', 'problem', 'someone', 'solution']
# ['version', 'control', 'show', 'usage']
# ['way', 'terminal', 'kernel', 'notebook', 'code', 'cell', 'code', 'terminal', 'bottom', 'screen', 'space', 'documentation', 'browser']
# []
# ['time']
# ['thing', 'use']
# ['code', 'editor', 'text', 'editor', 'copy', 'paste', 'code']
# ['way', 'hyracki']
# ['use']
# ['Difficulty', 'emacs']
# ['button', 'persistence', 'notebook', 'app', 'click', 'notebook']
# ['interface', 'notebook', 'notebook', 'notebook']
# ['slide', 'notebook', 'package', 'library', 'run', 'code']
# ['joy']
# ['drag', 'drop', 'version', 'control', 'json', 'ipynb', 'structure', 'cell', 'number', 'code', 'table', 'content', 'collapse', 'code', 'output', 'python', 'file', 'equivalent', 'notebook', 'table', 'content', 'collapsing', 'code', 'output', 'style', 'check', 'pylint', 'pyflake', 'line', 'user', 'feature']
# []
# ['version', 'control', 'bunch', 'cumbersome', 'directory', 'interface', 'jupyter']
# ['Inertia']
# ['fact', 'lot', 'option', 'cell', 'columns', 'markdown']
# ['debug', 'log', 'message', 'output', 'browser']
# ['web', 'text', 'editor', 'desktop', 'text', 'editor']
# ['UI']
# ['file', 'file', 'explorer']
# []
# ['lack', 'code', 're', 'use', 'beat', 'text', 'editor', 'something', 'import', 'order', 'workflow', 'console', 'qtconsole', 'editor']
# ['way', 'change', 'log', 'notebook']
# ['Lack', 'collaboration', 'platform']
# ['notebook', 'feature']
# ['vi', 'editing']
# ['startup', 'friction', 'track', 'reproducibility']
# ['scratch', 'pad', 'table']
# ['debugging', 'line', 'number', 'debug', 'mode', 'way', 'memory', 'filth']
# ['Inability', 'lab', 'stuff', 'lab', 'notebook']
# ['structure', 'hiding']
# ['cell', 'shell']
# ['format', 'math', 'notebook', 'code', 'package', 'code', 'seamless', 'code', 'editor', 'part', 'stuff', 'time', 'editor', 'step']
# ['head', 'switch', 'server', 'output']
# ['integration', 'editor', 'inspector', 'panel']
# ['control', 'pace', 'development', 'track']
# ['Installation', 'gospel']
# ['notebook', 'paragraphs', 'etc']
# ['support', 'tool', 'ad', 'hoc']
# ['code', 'cell', 'example', 'comment', 'area', 'code']
# ['Need', 'geologic', 'processing', 'python']
# ['Lack']
# ['ipython']
# ['work', 'exploratory', 'work']
# ['booboo', 'loop', 'button', 'interface']
# ['day', 'job', 'way', 'something', 'http', 'trinket', 'io', 'work']
# ['Speed', 'integration', 'Export', 'support', 'language', 'file', 'order', 'beta', 'cell', 'content', 'work', 'drop', 'group']
# ['cumbersome', 'cell', 'manipulation', 'support']
# ['ssh', 'issue', 'js', 'call']
# ['Ease', 'installation', 'language', 'support']
# ['legacy']
# []
# ['screen']
# ['code', 'notebook', 'eg']
# ['purpose', 'programming', 'blow', 'software', 'convenience', 'flexibility', 'convenience', 'while']
# ['version', 'control', 'integration']
# ['keyboard', 'vim']
# ['basis', 'work', 'machine', 'bit', 'notebook', 'render', 'work']
# []
# []
# ['nbconvert', 'absense', 'nbdiff', 'nbmerge']
# ['time', 'collaboration', 'la']
# ['integration', 'box', 'version', 'work']
# ['exporting', 'lot', 'math', 'notebook', 'share', 'pdf', 'copy', 'team', 'Jupyter']
# ['development', 'text', 'editor', 'python', 'coding', 'auto', 'tab']
# ['thing', 'tool']
# ['time', 'day', 'work']
# ['work']
# ['Difficult', 'information', 'iPython', 'transition', 'naming', 'university', 'engineering']
# ['lot', 'work', 'console']
# ['saving', 'version', 'control']
# ['work', 'version', 'control', 'code', 'review', 'risk', 'connect', 'kernel', 'ipython', 'dev', 'environment', 'application', 'jupyter', 'notebook', 'interface', 'context', 'ipython', 'kernel']
# ['analysis', 'fact', 'browser']
# ['explorer', 'standalone', 'desktop', 'application', 'desktop', 'application']
# ['usability', 'performance']
# ['collaboration']
# ['Lack', 'debugger']
# ['editor', 'style', 'paper', 'jupyter', 'title', 'document', 'integration', 'removal', 'blobs', 'view', 'notebook']
# ['printout', 'print']
# ['Lack', 'time', 'workflow', 'integration', 'code', 'line', 'line', 'style']
# ['part', 'lack', 'python', 'panel', 'vim', 'code']
# ['experience']
# ['setup', 'way', 'notebook', 'diff']
# ['etc', 'work', 'shifting', 'type', 'platform', 'server', 'notebook', 'workflow', 'way', 'ability', 'word', 'field']
# ['lot', 'server', 'auth']
# ['ruby', 'support']
# ['table', 'input', 'array']
# ['Lack', 'code', 'completion']
# ['lack', 'editor', 'vim', 'web']
# ['search', 'lack']
# ['package', 'anaconda', 'environment', 'command', 'line']
# ['Everything']
# ['matlab']
# ['Computing', 'part', 'work', 'prototyping', 'part', 'interface', 'docx']
# ['enviroment', 'editor', 'atom', 'cell', 'anything', 'notebook', 'support', 'language', 'party', 'kernel']
# ['engine']
# ['cell', 'cut', 'paste']
# ['completion', 'history', 'https', 'github', 'com', 'ipython']
# ['notebook', 'work', 'code', 'word']
# ['time', 'support', 'keyboard', 'notebook', 'notebook', 'format', 'version', 'control', 'pain', 'fact', 'code', 'content', 'content', 'live', 'file', 'content', 'presentation']
# []
# []
# ['difficulty', 'editor', 'clumsiness', 'browser', 'shortcut']
# ['advance', 'editing', 'vim', 'emacs', 'cell']
# ['Integration', 'text', 'editor']
# ['view', 'spyder']
# ['need', 'cloud', 'share', 'collaborate']
# ['work', 'batch', 'mode', 'use', 'version', 'control', 'merging']
# ['export', 'slide']
# ['ability', 'file']
# ['notebook']
# ['Lack', 'text', 'editor', 'editor']
# ['lack', 'interface', 'cluster']
# ['Difficulty', 'python']
# ['visibility', 'style', 'knowledge', 'documentation', 'position', 'cell', 'contrast', 'comment', 'difficulty', 'debugging', 'documentation', 'development']
# ['app', 'terminal', 'window', 'browser', 'window', 'bit', 'schlep']
# ['interaction', 'modal', 'editing', 'cell', 'accident', 'modal', 'design']
# ['Lack', 'interconnection', 'non', 'customization', 'native', 'spell', 'checker']
# ['spell', 'checker', 'trivial', 'customization', 'read', 'access']
# ['sage', 'kernel']
# ['lot', 'code', 'module', 'workflow', 'optimization', 'productivity', 'kernel', 'decision', 'keyboard', 'shortcut', 'slowdown']
# ['Version', 'notebooks', 'notebook', 'challenging', 'person', 'notebook', 'platform', 'demos', 'resource', 'simulation', 'point', 'upstart', 'programming', 'experience', 'notebook', 'way', 'web', 'python', 'etc', 'code', 'execute', 'startup', 'gui']
# ['text', 'cell', 'manipulation']
# ['fan', 'browser', 'hindrance', 'exploration', 'exploratory', 'programming', 'nutshell', 'web', 'interface', 'console', 'interface', 'experimentation', 'reason', 'console', 'day', 'day', 'work', 'mind', 'preference', 'communication', 'tool', 'implementation', 'fit', 'experimentation', 'opinion']
# ['core', 'support', 'vim', 'core', 'support', 'git']
# ['change', 'matlab', 'programming', 'intergration']
# ['time', 'ipython', 'shell', 'notebook', 'share']
# ['network', 'plotting']
# ['movement', 'algorithm', 'notebook', 'top', 'notebook']
# ['way', 'distro', 'python', 'org']
# ['version', 'control', 'system']
# ['way']
# ['requirement', 'execution', 'modulazation', 'call', 'cell', 'notebook', 'anything', 'reluctance']
# ['keyboard']
# ['part', 'workflow', 'support']
# ['day', 'job', 'manage', 'cluster', 'part', 'work']
# ['documentation', 'cookbook', 'style', 'compilation', 'use', 'variety', 'use']
# ['Lack', 'iPad', 'browser', 'support', 'input']
# ['Nothing']
# ['desktop', 'UI']
# ['python']
# ['text', 'feature', 'lack', 'thereof', 'structure']
# ['inability', 'structure', 'usability', 'problem']
# ['tool', 'today', 'backend', 'service']
# ['Difficult', 'code']
# ['legacy']
# ['mortem']
# ['integration']
# ['task', 'package', 'code', 'example']
# ['editor', 'part']
# ['lot', 'notebook', 'widget', 'support', 'something', 'team']
# ['usability', 'keyboard', 'usage', 'mouse', 'eg', 'input', 'field', 'use', 'eg', 'menus', 'cheat', 'sheet', 'today', 'help', 'integration', 'programming', 'language', 'libs', 'function', 'stuff', 'start', 'help']
# ['Support', 'proxy']
# ['install']
# ['editor']
# ['Difficult']
# ['language']
# ['time']
# ['Speed']
# ['integration', 'user', 'organization', 'work', 'work']
# ['lack', 'use', 'part', 'thing', 'integration', 'development', 'workflow', 'notebook', 'unit']
# ['document', 'display']
# ['Legacy', 'infrastructure']
# ['Nothing', 'development']
# ['ability', 'closer', 'selection']
# ['environment']
# ['line', 'line', 'number', 'exception', 'line', 'number']
# ['notebook', 'style', 'style']
# ['conda']
# ['block', 'selection']
# ['editor', 'keyboard', 'text', 'atom', 'way', 'code', 'text', 'editor', 'complexity', 'boilerplate', 'initialization', 'suite', 'code']
# []
# ['cell', 'output', 'loss', 'epoch', 'output', 'lot', 'wall', 'text']
# ['forth', 'notebook', 'editor', 'time', 'consuming']
# ['frequency', 'usage', 'part', 'workflow', 'editing', 'increase', 'entail', 'pain', 'experience', 'issue', 'use', 'future']
# ['haskell', 'support']
# ['murder', 'format', 'notebook', 'code', 'line', 'numbering']
# []
# ['identification', 'site', 'password', 'function']
# ['interface', 'isn', 'width', 'window', 'time', 'cell']
# ['Jupyter', 'code', 'project', 'work', 'file', 'processing', 'visualization', 'project', 'script']
# ['way', 'space', 'information', 'density', 'text', 'editor']
# ['work', 'nature', 'side', 'time']
# ['text', 'editor', 'disorganization']
# ['None', 'stuff', 'python', 'system', 'damper', 'ipython', 'jupyter', 'package', 'rename', 'gotcha', 'process', 'pain', 'stuff', 'anaconda', 'centric', 'confusion', 'system', 'vs', 'macs', 'none', 'specific', 'process', 'pandas', 'etc']
# ['gap', 'code']
# ['application', 'iOS', 'version', 'toolkit', 'version', 'flow', 'system', 'integration', 'application', 'iOS', 'part', 'workflow', 'desk', 'platform']
# ['code', 'system', 'notebook', 'file']
# ['simpler']
# ['bit', 'convenient', 'command', 'line', 'shell', 'use']
# ['notebook', 'project', 'management', 'instance', 'notebook', 'page', 'means', 'cohesive', 'program']
# ['time', 'scientist']
# ['performance']
# ['cluster', 'port', 'forwarding']
# ['code']
# ['jupyter', 'dashboard', 'documentation', 'mode']
# ['code', 'notebook', 'copy', 'code', 'content']
# ['lot', 'way', 'notebook', 'cloud', 'access', 'multi', 'experience']
# ['support', 'setup', 'work', 'computer', 'machine', 'something', 'friend', 'jupyter']
# ['interchange', 'markdown', 'copy', 'text', 'notebook', 'isn', 'documentation', 'way', 'notebook', 'server', 'viewing', 'browser', 'notebook']
# ['startup', 'cost', 'shell']
# ['table', 'mode', 'notebook', 'script', 'notebook', 'code', 'experiment', 'code', 'file']
# ['work', 'security', 'execution', 'code']
# ['day', 'job']
# ['dependency', 'threat', 'license', 'list', 'problem', 'etc', 'team', 'thing', 'bit', 'editor', 'autocompletion', 'wise', 'view', 'bit', 'programmer', 'side']
# ['setup']
# ['region', 'comment', 'block', 'multiple']
# ['language']
# ['Lack', 'app', 'browser']
# ['Ability', 'notebook', 'server', 'memory', 'spin', 'instance', 'hour', 'storage', 'github', 'security', 'language', 'development', 'notebook']
# ['fidelity']
# ['need']
# ['idea', 'stab', 'dark', 'namespace', 'function', 'name', 'cell', 'cell', 'error', 'cell', 'function', 'notebook', 'cell', 'change', 'function', 'something', 'notebook', 'kind', 'faster']
# ['work', 'introspection', 'autocompletion']
# ['python', 'science', 'libs', 'extension']
# ['jupyter']
# ['workflow', 'tool', 'group']
# ['computer']
# ['lack', 'possibility', 'notebook', 'lack', 'notebook']
# ['need', 'type', 'work']
# ['Integration', 'notebook', 'notebook', 'code', 'integration']
# ['python', 'editor', 'restart', 'import']
# ['track', 'number', 'cut', 'cell', 'time']
# ['comment']
# ['browser', 'ipython', 'session', 'jupyter', 'tab', 'figure', 'jupyter', 'tab', 'analysis', 'ipython', 'session', 'memory', 'freedom', 'mess', 'ordering', 'cell', 'execution', 'ipython', 'session', 'ipynb', 'file', 'quick', 'analysis', 'file', 'browser', 'command', 'lot', 'output', 'worksheet', 'autoreload', 'autoreload', 'doesn', 'work', 'doesn', 'work', 'problem', 'ipython', 'issue', 'notebook', 'state', 'kernel', 'everything', 'memory']
# ['work', 'notebook', 'editor', 'use', 'editing', 'notebook']
# ['software', 'support', 'graphs', 'matplotlib']
# []
# ['solution', 'notebook', 'script', 'exploration', 'production', 'product']
# ['report', 'generation', 'format', 'org', 'mode']
# ['integration']
# ['problem', 'se', 'something', 'ecosystem', 'notebook', 'hacking', 'process', 'visualisation', 'copy', 'matlab', 'output', 'image', 'format', 'notebook', 'display', 'visualisation', 'inordinate', 'ammount', 'time', 'notebook']
# ['Time']
# ['RStudio']
# ['use', 'multi', 'file', 'development', 'file', 'file', 'workflow', 'non', 'relationship', 'execution', 'development', 'code', 'execution', 'order', 'order', 'combination', 'call', 'graph', 'cell', 'below', 'cell', 'ordering', 'track', 'result', 'work', 'copy', 'paste', 'code', 'text', 'editor', 'snippet']
# ['share', 'notebook', 'co', 'notebook', 'file', 'association', 'notebook', 'python']
# ['track', 'number']
# ['jupyter', 'experimentation']
# ['format', 'notebook', 'content', 'markdown']
# ['instance', 'terminal', 'browser', 'thing', 'wrapper', 'server']
# []
# ['codemirror', 'javascript', 'inability', 'browser', 'vim']
# ['integration', 'jupyter', 'server', 'browse', 'folder', 'notebook', 'energy']
# ['barrier', 'notebook', 'script', 'ipython', 'time']
# ['development', 'development', 'mathjax', 'painless', 'integration', 'isn']
# ['Lack', 'integration', 'editor', 'choice']
# ['mode', 'la', 'default', 'setting', 'notebook', 'demo', 'notebook', 'repo']
# ['part', 'job']
# ['diffrent', 'color', 'scheme']
# ['code']
# ['Lack', 'support']
# []
# ['Inoperability', 'house']
# ['trouble', 'history', 'training']
# ['command', 'line', 'editor']
# ['form', 'text']
# ['Nothing']
# ['running', 'cell', 'response']
# ['run', 'iOS', 'iPhone', 'iPad']
# ['Lack', 'support', 'vimrc']
# []
# []
# ['access', 'browser', 'issue', 'past']
# []
# []
# ['editor']
# ['Presentation', 'code', 'version', 'control']
# ['shift', 'perspective', 'emacs', 'web', 'browser']
# ['Lack', 'ide']
# ['Stability']
# ['notebook', 'function', 'time', 'code', 'time', 'kernel', 'python', 'julia', 'module', 'editor', 'kernel', 'notebook', 'cell', 'type', 'editor', 'ide', 'file', 'browser']
# ['lack', 'modularity', 'code', 'reuse', 'state', 'burden', 'size']
# ['use', 'python', 'work']
# ['embedding', 'ipynb', 'file', 'insufficient', 'support', 'find', 'document', 'model', 'cell', 'editor']
# ['debugging', 'rstudio', 'visualisation']
# ['theme', 'interaction', 'support', 'pudb', 'ipdb', 'pdbpp', 'wdb', 'way', 'monitoring', 'code', 'command', 'pip', 'input']
# ['integration', 'code']
# ['Friction', 'kernel', 'machine']
# ['kind', 'export', 'cell', 'support', 'content', 'cell', 'source', 'file', 'eg', 'py', 'jl']
# ['app', 'part', 'server', 'browser', 'solution', 'creation']
# ['team', 'pain', 'notebook']
# ['integration', 'batch']
# ['science']
# ['Nothing']
# ['driven', 'bit', 'emacs', 'layer', 'layer', 'version', 'control', 'source', 'separate', 'nbconvert', 'notebook']
# ['notebook']
# ['text', 'selecting']
# ['environment', 'multi', 'user', 'server', 'jupyterhub', 'end', 'custom', 'authenticator', 'load', 'year']
# ['development', 'model', 'software', 'development', 'typing', 'slow', 'software', 'design', 'unit', 'provenance', 'situation', 'fact', 'prototype', 'software', 'development', 'notebook', 'setting', 'notebook', 'cursory', 'exploration', 'design', 'unit', 'testing', 'environment']
# ['interface', 'phosphor', 'js', 'notebook', 'cutomization']
# ['Nothing', 'infrastructure']
# ['Inability', 'notebook', 'software']
# ['tool', 'notebook', 'server', 'notebook', 'notebook', 'server', 'code', 'master', 'branch', 'branch', 'past', 'transcript', 'programming', 'session', 'support', 'idea', 'notebook', 'doesn', 'support', 'example', 'notebook', 'one', 'kernel', 'notebook', 'code', 'file', 'notebook', 'format', 'code', 'kernel', 'time', 'case', 'code', 'reload', 'module', 'code', 'file', 'notebook', 'reload', 'standing', 'problem', 'code', 'reload', 'cell', 'code', 'remain', 'cell', 'change', 'reload', 'code', 'cell', 'cell']
# ['web']
# ['editing', 'notebook', 'cell', 'toggling', 'output']
# ['work', 'install']
# ['use', 'code', 'notebook', 'doesn', 'work', 'context']
# ['integration']
# ['integration', 'text', 'editor']
# []
# ['way', 'kernel']
# ['keyboard', 'discovery', 'keyboard', 'lack', 'customization', 'readability', 'light']
# ['click', 'source', 'control', 'headache', 'module', 'notebook', 'reload', 'autoreload', 'don', 'running', 'kernel', 'way', 'kernel']
# ['page', 'code', 'anything']
# ['way', 'Notebook']
# ['way']
# ['project']
# ['integration']
# ['table', 'command', 'line']
# ['code']
# ['memory', 'use', 'hope', 'graphs', 'isn', 'exploration', 'use', 'case']
# ['state', 'cell', 'cell', 'time', 'cell', 'keyboard', 'shortcut', 'notebook', 'execution', 'cell', 're']
# ['jupyter', 'pip', 'software', 'distribution', 'mismatch', 'iPython', 'vs', 'jupyter', 'pass', 'framework']
# ['language', 'support', 'share', 'access']
# ['task', 'cursor', 'screen', 'help', 'window', 'cursor', 'way', 'thing', 'something', 'notebook', 'example', 'outline']
# ['Lack', 'completion', 'syntax']
# ['system']
# ['control', 'version', 'control']
# ['difficulty', 'version', 'control', 'person', 'experience', 'git', 'ipynb']
# ['reason', 'output', 'help', 'documentation', 'web', 'workflow']
# ['collaboration', 'time', 'google', 'docs']
# ['Lack', 'intellisense']
# ['performance', 'codemirror', 'vim']
# ['work']
# ['integration', 'pain', 'ass', 'structure', 'everything', 'work']
# ['notebook', 'analysis', 'interface', 'way', 'documentation']
# ['app', 'something']
# ['default']
# ['bit']
# []
# ['Effort', 'analysis', 'la']
# ['auto', 'highlighting', 'etc']
# ['time']
# ['code', 'completion', 'tooling', 'lot', 'source', 'integration', 'require', 'code']
# ['work', 'ability', 'ipython']
# ['research']
# ['pain', 'point', 'notebook', 'node', 'ram', 'power', 'browser', 'bottleneck']
# ['export', 'code', 'option', 'conversion']
# ['top', 'head', 'text', 'editor', 'interface', 'control', 'collaboration', 'merge', 'guess']
# ['library', 'analysis', 'prototyping', 'bit', 'hassle']
# ['notebook', 'mode', 'mode', 'someone', 'brain', 'way']
# ['code', 'browser', 'day', 'text', 'editor', 'way', 'notebook', 'code', 'test', 'format', 'markdown', 'project', 'com']
# []
# ['Availability']
# ['lack', 'debugger']
# []
# ['iOS', 'client', 'support', 'buy', 'core', 'engineering', 'team']
# ['access', 'history', 'arrow', 'etc', 'ipython', 'shell', 'notebook']
# ['editing', 'environment']
# ['project']
# ['integrate']
# ['work', 'front', 'computer', 'analysis', 'bit', 'indication']
# ['Compatibility', 'pentadactyl']
# ['need']
# ['luck']
# ['friction', 'launch', 'browser', 'notebook', 'comfort', 'editor', 'command', 'line']
# ['reusability', 'code']
# ['find', 'functionality']
# ['workflow']
# ['lot', 'notebook', 'coding', 'etc', 'something', 'notebook', 'problem', 'organisation', 'notebook', 'fault']
# ['issue', 'python', 'install']
# []
# ['paste', 'kind', 'cognizant']
# ['depth']
# ['support']
# ['documentation', 'configuration', 'stuff']
# ['Nothing']
# []
# ['toolbar', 'diff', 'version', 'control']
# ['language', 'java']
# []
# ['need', 'cloud']
# ['Difficult', 'code', 'notebook', 'module', 'stage']
# ['completion', 'indentation', 'etc']
# ['management', 'time']
# ['anything', 'ram']
# ['Difficulty']
# ['time', 'use', 'jupyter']
# ['graphs', 'power', 'notebook', 'environment']
# ['namespace', 'pollution', 'inability']
# ['control', 'look', 'team', 'style']
# []
# []
# ['notebook', 'memory', 'hog', 'time', 'code', 'command', 'line', 'navigation']
# ['control', 'integration', 'notebook', 'git', 'python', 'trip']
# ['Nothing', 'time']
# ['documentation', 'tutorial']
# ['plot', 'exploration', 'matplotlib', 'bit', 'example', 'code', 'plot', 'cell', 'order', 'plot', 'matplotlib', 'way', 'plot', 'element', 'color', 'delete', 'curve', 'matplotlib', 'course', 'part', 'package', 'moment', 'report', 'share', 'notebook', 'way', 'code', 'output', 'cell', 'hidden', 'code', 'example', 'bit', 'code', 'bit', 'lot', 'code', 'cell', 'order', 'notebook', 'script', 'notebook', 'order', 'order', 'way', 'cell', 'cell']
# ['matlab']
# ['integration', 'matplotlib', 'resizing', 'graph', 'redraw', 'run', 'code', 'cell', 'version', 'course', 'time', 'collaboration', 'notebook', 'step', 'thaat', 'level', 'code', 'move', 'cell', 'way', 'structure', 'notebook']
# ['code', 'print', 'way', 'block', 'code', 'text', 'par', 'text']
# ['analysis', 'way']
# ['rstudio', 'offer']
# ['df', 'style', 'autoreload']
# ['majority', 'work', 'share', 'code', 'use', 'setup']
# ['code', 'way']
# ['Enterprise', 'adoption']
# ['tool', 'jupyter', 'editor', 'jupyter']
# []
# ['enfancy', 'citation', 'etc']
# ['Lack', 'type', 'view', 'pandas', 'la', 'rstudio']
# ['Lack', 'way', 'group', 'cell']
# ['Lack', 'ease', 'work', 'code']
# []
# ['notebook', 'interface', 'analysis', 'workbench']
# ['lack', 'debugging', 'lack']
# ['Lack']
# ['design', 'ipynb', 'file', 'format', 'git']
# ['spell', 'spelling', 'idiot', 'perception']
# ['control', 'hide']
# ['exploration', 'etc', 'notebook']
# ['Acceptance', 'support', 'company']
# ['acquisition', 'analysis', 'code']
# ['time', 'visualization', 'need', 'javascript', 'custom', 'lack', 'class', 'support']
# ['Lack', 'find', 'feature']
# ['mouse']
# ['Difficulty', 'version', 'control', 'code', 'folding', 'interoperability', 'python', 'source', 'decision', 'everybody']
# ['notebook', 'way', 'notebook', 'way', 'dataset', 'memory', 'lot', 'time', 'file', 'restart']
# ['interaction']
# ['language', 'compatibility', 'jupyter', 'language', 'spark', 'groovy', 'clojure', 'etc']
# ['Nothing', 'code', 'notebook']
# ['part', 'workflow', 'example', 'teaching', 'lot', 'visualization', 'version', 'shell']
# ['startup', 'procedure']
# ['box', 'support', 'export', 'code', 'cell']
# ['integration', 'notebook', 'testing', 'while', 'set']
# ['clojure']
# ['lack', 'version', 'control', 'git', 'knowledge']
# ['polyglot', 'notebook']
# ['notebook', 'server', 'look', 'notebook', 'content', 'git', 'pain']
# ['code', 'editor']
# []
# ['linearity', 'lack', 'automatability', 'inability', 'code', 'module', 'nonlinearity']
# ['server', 'access']
# []
# ['Nobody', 'company']
# ['School']
# ['Lack', 'editing', 'support', 'multi', 'language', 'notebook', 'support']
# ['code', 'analysis', 'project', 'change', 'notebook', 'notebook', 'deletion', 'version', 'py', 'work', 'notebook', 'cut', 'cell', 'action', 'cell', 'preprocessing', 'memory', 'notebook']
# ['Option', 'side', 'screen', 'output', 'split', 'output', 'cell']
# ['Inability', 'diff', 'way', 'text', 'editor', 'way', 'feature', 'auto', 'indentation']
# ['time', 'workflow']
# ['lack', 'copy', 'paste', 'lack', 'access', 'multi', 'cursor', 'notebook', 'side', 'side', 'browser', 'source', 'code', 'environment', 'tmux']
# ['project', 'multi', 'file', 'kernel']
# ['text', 'editor', 'integration']
# ['track', 'order', 'look', 'feel', 'notebook', 'toolbar']
# ['debugger', 'result', 'code']
# []
# ['core', 'tool']
# ['text', 'editor', 'terminal']
# []
# []
# ['format', 'doesn', 'work', 'code', 'editor', 'text']
# ['lack', 'autocomplete', 'notebook', 'editor', 'notebook', 'analysis']
# ['industry', 'work']
# []
# ['Collaboration', 'support']
# ['data', 'history', 'work']
# ['notebook', 'source', 'control', 'diff', 'tool']
# ['access', 'instance', 'access', 'mysql']
# ['scheduler', 'exporter', 'order', 'production']
# ['programming', 'work', 'web', 'server']
# ['part', 'workflow']
# ['truth', 'software', 'development', 'analysis', 'case', 'something', 'bit', 'resource', 'code', 'kernel', 'error', 'command', 'line', 'ability', 'code', 'addition']
# ['notebook', 'import', 'command', 'thing', 'time']
# ['text', 'editor', 'behaviour']
# ['code', 'review', 'software', 'doesn', 'plugin', 'review', 'code']
# ['production', 'code', 'exploratory', 'tool']
# ['integration', 'version', 'control', 'transition', 'notebook', 'script', 'report', 'generation', 'code', 'library', 'editing', 'factor']
# ['code', 'editing', 'refactoring', 'while']
# ['workflow']
# ['notebook', 'productivity']
# ['server', 'spot', 'instance', 'time', 'image', 'instance', 'process']
# ['use', 'screen', 'space', 'notebook', 'user', 'support', 'management']
# ['control']
# ['Integration']
# ['proof', 'documentation', 'website', 'guarantee', 'surge', 'number', 'notebook']
# ['Inability', 'class', 'analysis', 'demoed', 'result', 'python', 'my_notebook', 'ipynb', 'process', 'script', 'time', 'shell', 'script', 'argparse', 'case', 'output', 'notebook', 'class', 'support', 'notebook', 'version', 'control', 'logic', 'metadata', 'cell']
# ['interoperability', 'ide', 'intellij']
# ['editor', 'option', 'extension', 'code', 'cell', 'text', 'editor', 'test', 'spell', 'check']
# ['command', 'line', 'code']
# ['text', 'python', 'code']
# ['Conversion', 'word', 'docs', 'bu', 'notebook']
# ['collaboration']
# []
# ['notebook', 'keyboard', 'shortcut', 'notebook', 'keyboard', 'menu', 'notebook', 'git', 'notebook', 'git', 'branch', 'list', 'viewer', 'wiki', 'python', 'evolution', 'https', 'westurner', 'python', 'https', 'github', 'com', 'westurner', 'gh', 'https', 'pypi', 'python', 'org', 'pypi', 'runipy']
# []
# ['support', 'computation']
# ['interaction']
# []
# ['Nothing', 'notebook', 'day', 'perform', 'document', 'research']
# ['editing', 'toolset', 'notebook', 'figure', 'latex', 'workflow']
# ['session', 'terminal', 'type', 'ipython', 'notebook', 'notebook', 'text', 'script', 'way', 'try', 'icon', 'documentation', 'customisation', 'document', 'notebook', 'use', 'custom', 'index', 'menu', 'something', 'html', 'code', 'coding', 'practice']
# ['Difficulty', 'generation', 'document']
# ['Lack', 'equation', 'numbering', 'referencing', 'table']
# ['lack', 'flexibililty', 'multiple', 'multi', 'cell', 'copy', 'paste']
# ['notebook', 'wrangling', 'visualisation', 'ideal']
# ['triviality', 'sharing', 'exchange', 'synergy', 'server', 'versus', 'user', 'installation', 'sparse', 'documentation', 'configuration']
# ['interface', 'power', 'vim', 'editor']
# ['keyboard']
# ['control', 'scripting']
# ['power', 'text', 'file', 'editor', 'syntax', 'check', 'introspection', 'integration']
# ['Collaboration']
# ['workplace']
# ['notebook', 'line', 'script', 'module']
# ['Compliance']
# []
# ['insertion', 'report', 'paper', 'suppression', 'code', 'cell', 'output', 'display']
# ['text', 'editor', 'tool', 'development', 'part', 'work', 'notebook', 'hindrance']
# ['use']
# ['Lack', 'diff', 'ing', 'use', 'source', 'control']
# []
# ['work', 'development', 'environment']
# ['Ease', 'integration', 'command', 'line', 'lack', 'unit']
# ['Utility', 'notebook', 'interface', 'folding', 'manipulation', 'notebook', 'paper']
# ['Habit']
# ['text', 'editor', 'notebook', 'code']
# []
# ['lot', 'design', 'work']
# []
# ['management', 'disaster', 'management', 'analysis']
# ['multi', 'cell']
# ['edit', 'browser', 'notebook', 'plugin']
# ['history', 'export']
# ['part', 'export', 'word', 'openoffice', 'format']
# ['text']
# ['need', 'ipython', 'terminal', 'console', 'start', 'oneliner', 'work']
# ['mode', 'default']
# ['documentation']
# ['integration', 'extension']
# ['Lack', 'debugger']
# ['keyboard', 'guy', 'mouse', 'interface', 'bit', 'bother', 'server', 'tab', 'server']
# ['workspace']
# ['version', 'git']
# ['doesn', 'software', 'development', 'line', 'execution']
# ['collaboration', 'kernel', 'doesn', 'hinder', 'maintainability']
# ['Lack', 'integration', 'integration', 'task', 'exploration', 'view', 'problem']
# ['keyboard', 'reason', 'design', 'text', 'atom', 'productivity']
# ['line', 'line', 'overhead', 'doc']
# ['interface']
# ['use', 'python', 'support', 'scala']
# ['functionality', 'version', 'control']
# ['Lack', 'diff', 'merge', 'capability', 'generation', 'link', 'looonng', 'fan', 'browser', 'priority', 'fan', 'mode', 'latex', 'numbering', 'cross', 'reference']
# []
# ['Inability', 'wordpress', 'code', 'bit', 'hassle', 'notebook', 'use', 'tunneling', 'fine', 'copy']
# []
# ['notebook', 'workaround', 'https', 'github', 'com', 'jupyter', 'atom', 'notebook', 'https', 'github', 'com']
# ['way', 'proliferation', 'way', 'order']
# ['lack', 'debug', 'support', 'code']
# ['browser']
# ['lecture', 'lack', 'code', 'editor', 'searching', 'view', 'navigation', 'presentation', 'work', 'thing', 'work', 'help', 'command', 'window', 'help', 'text', 'help', 'number', 'work', 'burden', 'tool', 'learning', 'curve', 'bit', 'math', 'bit', 'typos', 'prevent', 'equation', 'cross', 'integration', 'documentation']
# ['command', 'line', 'launcher', 'app', 'machine', 'command', 'line', 'example', 'navigate', 'directory', 'lot', 'notebook', 'client', 'place']
# ['Notebook', 'space', 'python', 'module', 'code']
# ['pipeline', 'command', 'line']
# ['difficulty', 'multiuser', 'classroom', 'environment', 'difficulty', 'widget', 'framework', 'demos']
# ['search']
# ['vim', 'incl']
# []
# ['notebook', 'workaround', 'https', 'github', 'com', 'jupyter', 'atom', 'notebook', 'https', 'github', 'com']
# ['Inability', 'code', 'code', 'package', 'module', 'notebook', 'notebook', 'everything', 'outside', 'notebook', 'environment', 'lot', 'infrastructure', 'module', 'code', 'notebook', 'version', 'control', 'stream', 'notebook', 'software', 'development', 'notebook', 'module', 'way', 'street', 'inconsistency', 'import', 'software', 'notebook', 'module', 'nature', 'notebook', 'source', 'variety', 'convention', 'path', 'relative', 'location', 'notebook', 'server', 'vs', 'notebook', 'documentation', 'notebook', 'source', 'code', 'documentation', 'cell', 'docstring', 'function', 'class', 'method']
# ['Unfamiliarity']
# ['feature', 'refactor', 'code', 'code']
# ['university', 'standard']
# ['secure', 'sharing', 'computer', 'savvy']
# []
# ['documentation']
# ['control', 'version', 'control']
# ['Support', 'programming', 'notebook']
# ['editor', 'browser', 'file', 'folder', 'manager', 'multi', 'file', 'pdb', 'command', 'completion', 'history']
# ['fact', 'bash', 'kernel', 'bash_metakernel', 'cygwin', 'sync', 'fact', 'command', 'line', 'stuff', 'time', 'laptop', 'fan', 'sense']
# ['word', 'completion']
# ['startup', 'server', 'directory', 'base', 'notebook', 'dricetory', 'contrast', 'notebook']
# ['impedance', 'mismatch', 'version', 'control', 'lack', 'level', 'document', 'plugin']
# ['Lack', 'persistence']
# ['functionality', 'access']
# ['basis']
# ['tool', 'lot']
# ['functionality']
# ['bit']
# ['code', 'editor', 'terminal', 'window', 'notebook']
# ['jupyter']
# ['Ease', 'version', 'control', 'gift', 'hub', 'input', 'syntax', 'highlighting', 'ease', 'side']
# ['panel', 'user', 'interface', 'matlab', 'ipython', 'form', 'cell', 'matlab', 'time', 'support', 'support', 'code']
# ['lot', 'space', 'lot', 'aspect', 'ratio', 'input', 'columns', 'input', 'output', 'minimap', 'import', 'exploration', 'bokeh', 'matplotlib', 'plot', 'interface']
# ['Integration', 'documentation', 'ho', 'version', 'control']
# ['Work', 'schedule']
# ['command', 'line']
# ['acceptance', 'tool', 'exploratory', 'analysis', 'excel', 'tableau', 'curve']
# []
# ['notebooks', 'pain', 'viewer', 'desktop', 'os', 'graph']
# ['code']
# ['experience', 'area', 'browser']
# ['pdf', 'install']
# ['top']
# ['way', 'code', 'document']
# ['support', 'collaboration', 'user', 'server', 'diff']
# ['Difficulty', 'use', 'output', 'time']
# ['moment']
# ['block', 'weakness', 'absence', 'cross', 'referencing', 'section', 'facility', 'block', 'way', 'code', 'pure', 'source', 'code', 'way', 'number', 'code', 'difficulty', 'example', 'js']
# ['editor', 'way', 'bit', 'script']
# ['explorer', 'tool', 'purpose', 'git', 'version', 'control', 'code', 'exploration', 'demos']
# ['backend', 'notebook', 'backend']
# ['version', 'bash', 'support', 'https', 'github', 'com', 'blob', 'master', 'ipynb']
# ['window', 'browser', 'integration', 'work']
# ['tool', 'job']
